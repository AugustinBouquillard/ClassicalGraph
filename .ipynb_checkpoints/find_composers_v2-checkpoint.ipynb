# %%
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

install("spacy")
# Out:
# Requirement already satisfied: spacy in /opt/anaconda3/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (78.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)

# %%
from composer import *
from bs4 import BeautifulSoup
import requests
import re
import networkx as nx
import spacy
import numpy as np
import math
import time
import pickle
import json
from ipysigma import Sigma
import matplotlib.pyplot as plt

# %% [markdown]
# ## NLP pour identifier des influences directes via les notices biographiques

# %%
"""cette cellule permet de retrouver tous les noms de compositeurs cités dans l'article wikipedia du compositeur d'intérêt et d'en dresser la liste dans un dictionnaire dont les clés sont les id des compositeurs en question"""

def get_person_entities(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    L=[]
    for ent in doc.ents:
        if ent.label_=='PERSON':
            #print(ent.text, ent.start_char, ent.end_char, ent.label_)
            L.append(ent.text)
    #print(L)
    return L
    
            
def get_wikipedia_page_metadata(name):
    language_code = 'en'
    search_query = name
    number_of_results = 1
    """headers = {
      # 'Authorization': 'Bearer ACCESS_TOKEN',
      'User-Agent': 'APP_NAME (EMAIL_OR_CONTACT_PAGE)'
    }"""
    base_url = 'https://api.wikimedia.org/core/v1/wikipedia/'
    endpoint = '/search/page'
    url = base_url + language_code + endpoint
    parameters = {'q': search_query, 'limit': number_of_results}
    response = requests.get(url, params=parameters)
    dico_response = json.loads(response.text)
    for page in dico_response['pages']:
      display_title = page['title']
      article_url = 'https://' + language_code + '.wikipedia.org/wiki/' + page['key']
      try:
        article_description = page['description']
      except:
        article_description = 'a Wikipedia article'
      try:
        thumbnail_url = 'https:' + page['thumbnail']['url']
      except:
        thumbnail_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Wikipedia-logo-v2.svg/200px-Wikipedia-logo-v2.svg.png'
        

def get_wikipedia_page_text_with_api(title):
    endpoint = "https://en.wikipedia.org/w/api.php"
    params = {
        'action': 'parse',
        'page': title,
        'format': 'json',
        'prop': 'text',
    }

    response = requests.get(endpoint, params=params)
    data = response.json()

    if 'parse' in data:
        html_content = data['parse']['text']['*']
        soup = BeautifulSoup(html_content, 'html.parser')
        text = soup.get_text()
        return text
    else:
        return "Page not found or error occurred"
    
def get_wikipedia_page_text(name,language="en"):
    url = f"https://{language}.wikipedia.org/w/index.php?search={name}"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    text=soup.get_text()
    if language =="en" and (name+" - Wikipedia" in text or name.split(" ")[-1]+" - Wikipedia" in text):
        return get_wikipedia_page_text(name+" (composer)")
    elif language=="fr" and (name+" - Wikipédia" in text or name.split(" ")[-1]+" - Wikipédia" in text):
        return get_wikipedia_page_text(name+" (compositeur)")
    return text

# %% [markdown]
# ## filtre pour ne conserver que les noms de compositeurs

# %%
def composer_filter_by_dict(list_of_names, dico):
    """filtre les noms qui sont ceux de compositeurs à partir d'un dictionnaire de compositeurs, évite d'avoir à rechercher dans wikidata à chaque fois donc plus rapide mais moins robuste, à compléter peut-être avec le TD qui utilisait des Trie"""
    list_of_names = list(filter(lambda x: x.strip() in dico, list_of_names))
    return list_of_names

#composer_filter_by_dict(["Richard Wagner","Bach","Mozart"],{"Richard Wagner":(1813,1883),"Johann Sebastian Bach":(1685,1750)})
        
def composer_filter_old(list_of_names):
    compo_dico={}
    for n in list_of_names:
        c_id = find_id(n)
        if c_id is not None and c_id not in compo_dico:
            c = is_composer(c_id,n)
            #print(is_composer(n))
            if c is not None :
                compo_dico[c_id]=c
                print(n,"is a composer")
    return compo_dico

def composer_filter(list_of_names):
    compo_dico={}
    cpt=0
    for n in list_of_names:
        c_id = find_id(n)
        if c_id is not None and c_id not in compo_dico:
            c = is_composer(c_id,n)
            #print(is_composer(n))
            if c is not None :
                if cpt==0:
                    compo=c
                compo_dico[c_id]=c
                print(n,f"is the composer number {cpt} found in {compo}'s page")
                cpt+=1
    return compo,compo_dico

#compo_dico=composer_filter(["Bach","Beethoven","Wagner"])
#print(compo_dico)
print(is_composer(find_id("Jean-Jacques Rousseau")))
print(find_id("Jean-Jacques Rousseau"))
# Out:
# Jean-Jacques Rousseau set()
# at the end of is_composer Jean-Jacques Rousseau Q6527 has influenced set()
# Jean-Jacques Rousseau
# Q6527

# %%
def find_compositional_influences(name,fr=False):#problème : l'algo saute souvent Beethoven, y compris chez Wagner
    content = get_wikipedia_page_text(name)
    if fr:
        content+=get_wikipedia_page_text(name,"fr")
    persons = get_person_entities(content)
    return(composer_filter(persons))

def build_list_of_influences(enum_of_composers,french=False):
    list_of_influ_dict=[]
    for composer in enum_of_composers:
        list_of_influ_dict.append(find_compositional_influences(composer,fr=french))
    return list_of_influ_dict

#compos = ["André-Ernest-Modeste Grétry","Ernest Chausson","Gabriel Dupont","Paul le Flem"]
#compos = ["Franz Lachner","Jean Cras"]
#compos = ["Henri Duparc"]

#list_of_dico=build_list_of_influences(compos,True)
#print(list_of_dico)

# %%
"""essayons de qualifier les relations d'influence entre compositeurs plus précisément qu'avec la seule présence de l'un dans la page wikipedia de l'autre"""
"""compléter avec les influences - même peu nombreuses - spécifiées dans wikidata"""
"""penser à prévoir le cas d'un compositeur encore vivant"""
"""ajouter une détection des liens vers des pages de compositeurs sur wikipedia"""
def orienting_with_dates_sparql(list_of_dico,influences={}):
    """returning an adjacency list from the dict of composers appearing in the wiki notice of the first one in the dict; orienting the influence relations when no doubt exists because of birth-death dates"""
    sparql_endpoint = "https://query.wikidata.org/sparql"
    for dico in list_of_dico:
        cpt=0
        for c in dico:
            #if c.birth is None or c.death is None:#à améliorer
            time.sleep(1)  # 0.5s between requests
            query = f"""
                    SELECT ?birth ?death WHERE {{
                        wd:{c} wdt:P569 ?birth.
                        wd:{c} wdt:P570 ?death.
                    }}
                    """
                
            if cpt>0:#the rest of the dict are the composers who may have or have been influenced our musician of interest "compo"
                response = requests.get(sparql_endpoint, params={'query': query, 'format': 'json'})
                print("Status Code:", response.status_code)
                #print("Response Text:", response.text)
                dates_dict = response.json()
                bindings = dates_dict.get("results", {}).get("bindings", [])
                if bindings:
                    birth_date = int(bindings[0].get("birth", {}).get("value").split("-")[0])                                                             #, "Unknown")
                    #c.birth=birth_date
                    death_date = int(bindings[0].get("death", {}).get("value").split("-")[0])
                    #c.death=death_date

                if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                    if c not in influences :
                        influences[c]=[]
                    influences[c].append(compo)
                elif birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                    influences[compo].append(c)
                else:#we cannot say anything for sure since they were contemporary so by default we assume they influenced each other 
                    influences[compo].append(c)
                    if c not in influences :
                        influences[c]=[]
                    influences[c].append(compo)

            else:#the first element of the dictionary is the composer we are interested in : "compo"
                compo = c
                if compo not in influences:
                    influences[compo]=[]
                response = requests.get(sparql_endpoint, params={'query': query, 'format': 'json'})
                dates_dict = response.json()
                bindings = dates_dict.get("results", {}).get("bindings", [])
                if bindings:
                    birth_date_compo = int(bindings[0].get("birth", {}).get("value").split("-")[0])
                                                                                 #, "Unknown")
                    #compo.birth=birth_date_compo
                    death_date_compo = int(bindings[0].get("death", {}).get("value").split("-")[0])
                    #compo.death=death_date_compo
                #else:
                #    birth_date_compo = "Unknown"
                #    death_date_compo = "Unknown"
                #print(birth_date_compo,death_date_compo)
                #if birth_date_compo != "Unknown" and death_date_compo != "Unknown"
                cpt+=1
        
    return influences

def orienting_with_dates_old(list_of_dico,influences={}):
    """returning an adjacency list from the dict of composers appearing in the wiki notice of the first one in the dict; orienting the influence relations when no doubt exists because of birth-death dates"""
    for dico in list_of_dico:
        cpt=0
        for c in dico.values():
            if cpt>0 :
                if c.birth is not None and c.death is not None :#the rest of the dict are the composers who may have or have been influenced our musician of interest "compo"
                    print("db:"+c.birth.split("-")[0].strip())
                    birth_date = int(c.birth.split("-")[0].strip())
                    print("intdb:"+str(birth_date))
                    death_date = int(c.death.split("-")[0].strip())
                    print(death_date)

                    if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                        if c not in influences :
                            influences[c]=[]
                        influences[c].append(compo)
                    elif birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        influences[compo].append(c)
                    else:#we cannot say anything for sure since they were contemporary so by default we assume they influenced each other 
                        influences[compo].append(c)
                        if c not in influences :
                            influences[c]=[]
                        influences[c].append(compo)

            else:#the first element of the dictionary is the composer we are interested in : "compo"
                compo = c
                if compo not in influences:
                    influences[compo]=[]
                #response = requests.get(sparql_endpoint, params={'query': query, 'format': 'json'})
                #dates_dict = response.json()
                #bindings = dates_dict.get("results", {}).get("bindings", [])
                #if bindings:
                if c.birth is not None and c.death is not None :
                    print("db:"+c.birth.split("-")[0].strip())
                    birth_date_compo = int(c.birth.split("-")[0].strip())
                    print("intdb:"+str(birth_date_compo)) #, "Unknown")
                    death_date_compo = int(c.death.split("-")[0].strip())#to do : prevoir un compositeur vivant...
                    print(death_date_compo)
                #else:
                #    birth_date_compo = "Unknown"
                #    death_date_compo = "Unknown"
                #print(birth_date_compo,death_date_compo)
                #if birth_date_compo != "Unknown" and death_date_compo != "Unknown"
                cpt+=1
    return influences

#print(list_of_dico)
#adj_list_sparql=orienting_with_dates_sparql(list_of_dico)
#adj_list=orienting_with_dates(list_of_dico)
#print(adj_list==adj_list_sparql)
#print(adj_list)

def orienting_with_dates(list_of_dico,compo_dico={}):
    """completing the influences of all encountered compsoers; orienting the influence relations when no doubt exists because of birth-death dates"""

    for compo,dico in list_of_dico:
        cpt=0
        b=False #boolean equal to True iff we have access the the birth date of the first composer
        d=False #boolean equal to True iff we have access the the death date of the first composer
        #print(dico)
        for c in dico.values():

            if c.id not in compo_dico :
                compo_dico[c.id]=c

            if cpt==0: #the first element of each dictionary is the one whose wikipedia page was used to retrieve all the others present in the current dictionary
                #compo = compo_dico[c.id]
                cpt+=1
                print("1st composer of this page :",compo,compo.id,compo_dico[compo.id].influences)
                birth_date_compo = compo.birth
                death_date_compo = compo.death
                if birth_date_compo is not None :
                    print("db:"+str(compo.birth))
                    b = True

                if death_date_compo is not None :
                    print("dd:"+str(compo.death))
                    d = True

            else :
                birth_date = c.birth
                death_date = c.death

                if d and birth_date is not None:
                    if birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        compo_dico[compo.id].influences.add(c)
                        print(f"added {c} to {compo_dico[compo.id]}")
                    elif b and death_date is not None:
                        if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                            compo_dico[c.id].influences.add(compo)
                            print(f"added {compo_dico[compo.id]} to {c}")
                        else:
                            compo_dico[compo.id].influences.add(c)
                            print(f"added {c} to {compo_dico[compo.id]} in the new way")
                            compo_dico[c.id].influences.add(compo)
                            print(f"added {compo_dico[compo.id]} to {c}")
                    else:
                        compo_dico[compo.id].influences.add(c)
                        print(f"added {c} to {compo_dico[compo.id]}")
                        compo_dico[c.id].influences.add(compo)
                        print(f"added {compo_dico[compo.id]} to {c}")

                elif b and death_date is not None:
                        if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                            compo_dico[c.id].influences.add(compo)
                            print(f"added {compo_dico[compo.id]} to {c}")
                        #elif d and birth_date is not None:
                        #    if birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        #        compo_dico[compo.id].influences.add(c)
                        else:
                            compo_dico[compo.id].influences.add(c)
                            print(f"added {c} to {compo_dico[compo.id]}")
                            compo_dico[c.id].influences.add(compo)
                            print(f"added {compo_dico[compo.id]} to {c}")

                else:#we cannot say anything for sure since they were contemporary so by default we assume they influenced each other
                    compo_dico[compo.id].influences.add(c)
                    print(f"added {c} to {compo_dico[compo.id]}")
                    compo_dico[c.id].influences.add(compo)
                    print(f"added {compo_dico[compo.id]} to {c}")
        print(compo_dico[compo.id],"has influenced",compo_dico[compo.id].influences)

    return compo_dico

# %%
def build_graph_from_adj_list(adj_list,G=nx.DiGraph()):
    #in_G_set = {}
    for compo in adj_list:
        #G.add_node(compo)
        #in_G_set.add(compo)
        for c in adj_list[compo]:
            #if c not in in_G_set:
                #G.add_node(compo)
            G.add_edge(compo,c)
    return G

#G=build_graph_from_adj_list(adj_list_sparql)
#nx.draw(G, with_labels=True)#, labels = nx.get_node_attributes(graph, 'nom complet'))

# %%
def graph_of_influences_old(list_of_compo_names):
    list_of_influ_dicts=build_list_of_influences(list_of_compo_names,True)#put false if you're only interested in the english wiki
    adj_list = orienting_with_dates_old(list_of_influ_dicts)
    return build_graph_from_adj_list(adj_list)
#G=graph_of_influences(["Henri Duparc","John Dunstable"])
#G=graph_of_influences(["Gabriel Dupont"])
#nx.draw(G, with_labels=True)#, labels = nx.get_node_attributes(graph, 'nom complet'))

# %%
#save graph object to file
#pickle.dump(G, open(str(next(iter(compo_dico.keys())))+".pickle", 'wb'))
# load graph object from file
#G = pickle.load(open('filename.pickle', 'rb'))
#nx.draw(G)

# %%
def build_graph_from_dict(compo_dico,G=nx.DiGraph()):
    for compo in compo_dico.values():
        print("in build_graph_from_dict",compo,"has influenced",compo.influences)
        for c in compo.influences:
            G.add_edge(compo,c)
            print(f"added {c} to {compo_dico[compo.id]}")
            
    # save graph object to file
    pickle.dump(G, open(str(next(iter(compo_dico.keys())))+".pickle", 'wb'))
    return G

def graph_of_influences(list_of_compo_names,fr=True,G=nx.DiGraph()):
    list_of_influ_dicts=build_list_of_influences(list_of_compo_names,fr)#put false if you're only interested in the english wiki
    compo_dico = orienting_with_dates(list_of_influ_dicts)
    return build_graph_from_dict(compo_dico,G)

#G1=graph_of_influences(["Henri Duparc","John Dunstable"])
#G1=graph_of_influences(["Gabriel Dupont"],False)
#G=graph_of_influences(["Olivier Messiaen"])
#G=graph_of_influences(["Henri Duparc","Gabriel Dupont","Jean Cras"],True)
G2=graph_of_influences(["Richard Wagner"],True)
#G=graph_of_influences(["Gabriel Dupont"],False,G)
# Out:
# Richard Wagner set()
# at the end of is_composer Richard Wagner Q1511 has influenced set()
# Richard Wagner is the composer number 0 found in Richard Wagner's page
# at the end of is_composer Hans Knappertsbusch Q57425 has influenced set()
# Siegfried Wagner {Hans Knappertsbusch}
# at the end of is_composer Siegfried Wagner Q143867 has influenced {Hans Knappertsbusch}
# Siegfried Wagner is the composer number 1 found in Richard Wagner's page
# at the end of is_composer Marie d'Agoult Q253453 has influenced set() no one since no pupil was found
# Marie d'Agoult is the composer number 2 found in Richard Wagner's page
# at the end of is_composer Gudrun Wagner Q67813 has influenced set() no one since no pupil was found
# Gudrun Wagner is the composer number 3 found in Richard Wagner's page
# at the end of is_composer Bettina Walker Q53032647 has influenced set()
# at the end of is_composer William Dayas Q16169825 has influenced set()
# at the end of is_composer Eloísa D’Herbil Q5829952 has influenced set()
# at the end of is_composer Carl Ludvig Hall Q5783822 has influenced set()
# at the end of is_composer Hilda Thegerström Q4982446 has influenced set()
# at the end of is_composer Julie Rivé-King Q4394342 has influenced set()
# at the end of is_composer Carl Filtsch Q577658 has influenced set()
# at the end of is_composer Hans von Bülow Q155540 has influenced set()
# Franz Liszt {Eloísa D’Herbil, William Dayas, Carl Filtsch, Carl Ludvig Hall, Bettina Walker, Hilda Thegerström, Hans von Bülow, Julie Rivé-King}
# at the end of is_composer Franz Liszt Q41309 has influenced {Eloísa D’Herbil, William Dayas, Carl Filtsch, Carl Ludvig Hall, Bettina Walker, Hilda Thegerström, Hans von Bülow, Julie Rivé-King}
# Franz Liszt is the composer number 4 found in Richard Wagner's page
# at the end of is_composer Franz Schubert Q7312 has influenced set() no one since no pupil was found
# Franz Schubert is the composer number 5 found in Richard Wagner's page
# at the end of is_composer Raoul Bardac Q15973497 has influenced set()
# Claude Debussy {Raoul Bardac}
# at the end of is_composer Claude Debussy Q4700 has influenced {Raoul Bardac}
# Claude Debussy is the composer number 6 found in Richard Wagner's page
# Erreur sur le nom la barre latérale
# masquer
# Erreur sur le nom Rechercher
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Apparence
# Erreur sur le nom la barre latérale
# masquer
# Erreur sur le nom la barre latérale
# masquer
# Erreur sur le nom LireModifierModifier le
# Erreur sur le nom la barre latérale
# masquer
# at the end of is_composer Hermann Levi Q61175 has influenced set() no one since no pupil was found
# Hermann Levi is the composer number 7 found in Richard Wagner's page
# Cosima Liszt
#
#
#  set()
# at the end of is_composer Cosima Liszt
#
#
#  Q75789 has influenced set()
# Cosima Liszt
#
#
#  is the composer number 8 found in Richard Wagner's page
# Erreur sur le nom annuel qu'il
# Erreur sur le nom intellectuel – ami de Mikhaïl Bakounine
# Erreur sur le nom par l'antisémitisme de son
# Erreur sur le nom enflammés de la part de
# Erreur sur le nom Biographie[modifier | modifier
# Erreur sur le nom ville du royaume de Saxe
# Erreur sur le nom greffier de la police
# Erreur sur le nom ] l'ami de Carl Friedrich
# Erreur sur le nom domicile de Geyer
# Friedrich Nietzsche set()
# at the end of is_composer Friedrich Nietzsche Q9358 has influenced set()
# Friedrich Nietzsche is the composer number 9 found in Richard Wagner's page
# Erreur sur le nom de ce douloureux secret de famille qu'il
# at the end of is_composer Caroline Ridderstolpe Q4974772 has influenced set()
# Carl Maria von Weber {Caroline Ridderstolpe}
# at the end of is_composer Carl Maria von Weber Q154812 has influenced {Caroline Ridderstolpe}
# Carl Maria von Weber is the composer number 10 found in Richard Wagner's page
# Erreur sur le nom dans laquelle l'influence de Carl Maria von Weber
# Erreur sur le nom accueillie avec peu d'enthousiasme.
# Erreur sur le nom homme qui la laisse
# Erreur sur le nom trouve néanmoins
# Erreur sur le nom avec peu d'espoir de pouvoir
# Erreur sur le nom peu apprécié
# Erreur sur le nom Avec L'Œuvre d'art de l'avenir
# Erreur sur le nom l’ami Pohl
# Erreur sur le nom personnelle sera
# Erreur sur le nom Selon Schopenhauer
# at the end of is_composer Hans Sachs Q19543 has influenced set() no one since no pupil was found
# Hans Sachs is the composer number 11 found in Richard Wagner's page
# Erreur sur le nom Selon Élisabeth de Fontenay
# Erreur sur le nom mal dégrossi
# Erreur sur le nom Dieu supplicié l'animal martyrisé
# Erreur sur le nom mari informé de ses
# Erreur sur le nom enflammée de Wagner à Mathilde
# Erreur sur le nom mais il continue de la soutenir
# Erreur sur le nom Louis II de Bavière[modifier
# Erreur sur le nom Il s'agit de la femme de Hans von Bülow
# Erreur sur le nom cadette de Wagner
# Erreur sur le nom Devant l'insistance de Louis II
# Erreur sur le nom il choisit la petite
# at the end of is_composer Blanche Lucas Q110224410 has influenced set()
# at the end of is_composer Eugène Grassi Q64485152 has influenced set()
# at the end of is_composer Emiliana de Zubeldia Q5371675 has influenced set()
# at the end of is_composer Edward Shippen Barnes Q5345314 has influenced set()
# at the end of is_composer Helena Munktell Q4968368 has influenced set()
# at the end of is_composer Paul Berthier Q3370629 has influenced set()
# at the end of is_composer Marcel Labey Q3289087 has influenced set()
# at the end of is_composer Blanche Selva Q2906016 has influenced set()
# at the end of is_composer László Lajtha Q956324 has influenced set()
# Vincent d'Indy {Marcel Labey, László Lajtha, Edward Shippen Barnes, Emiliana de Zubeldia, Blanche Selva, Blanche Lucas, Helena Munktell, Paul Berthier, Eugène Grassi}
# at the end of is_composer Vincent d'Indy Q313584 has influenced {Marcel Labey, László Lajtha, Edward Shippen Barnes, Emiliana de Zubeldia, Blanche Selva, Blanche Lucas, Helena Munktell, Paul Berthier, Eugène Grassi}
# Vincent d'Indy is the composer number 12 found in Richard Wagner's page
# Erreur sur le nom tente de réduire le
# Erreur sur le nom Pendant l'acte III de la
# Erreur sur le nom cœur mais continue de mener
# Erreur sur le nom il est emporté
# Erreur sur le nom musicales achevées
# Erreur sur le nom jamais représenté
# Erreur sur le nom voit la composition de Tristan
# Erreur sur le nom il se fit le défenseur
# Erreur sur le nom L'expressivité de l'orchestre est
# Erreur sur le nom d'Eugène Burnouf
# Erreur sur le nom Magdebourg[42
# Erreur sur le nom La Mort d'Isolde
# Erreur sur le nom acte de La Walkyrie
# Erreur sur le nom Les Murmures de la forêt
# Erreur sur le nom deuxième acte de Siegfried
# Erreur sur le nom acte de Parsifal
# Erreur sur le nom l'essentiel de son
# Erreur sur le nom longtemps appelée par
# Erreur sur le nom Thème de Porazzi
# Erreur sur le nom il se pencha de nouveau sur cette ébauche
# Erreur sur le nom interprétée de nos jours
# Erreur sur le nom tête de Richard Wagner
# at the end of is_composer l'orchestre joue Q102286130 has influenced set() no one since no pupil was found
# l'orchestre joue is the composer number 13 found in Richard Wagner's page
# Erreur sur le nom l'histoire de la musique de scène
# at the end of is_composer Wilhelm Furtwängler Q57285 has influenced set() no one since no pupil was found
# Wilhelm Furtwängler is the composer number 14 found in Richard Wagner's page
# Jacques Chailley set()
# at the end of is_composer Jacques Chailley Q1677932 has influenced set()
# Jacques Chailley is the composer number 15 found in Richard Wagner's page
# Erreur sur le nom Il s'agissait il est
# at the end of is_composer Thomas Attwood Q2422110 has influenced set()
# at the end of is_composer Barbara Ployer Q729164 has influenced set()
# at the end of is_composer Ignaz von Seyfried Q697804 has influenced set()
# at the end of is_composer Franz Xaver Süßmayr Q310518 has influenced set()
# at the end of is_composer Johann Nepomuk Hummel Q151953 has influenced set()
# Wolfgang Amadeus Mozart {Barbara Ployer, Thomas Attwood, Franz Xaver Süßmayr, Ignaz von Seyfried, Johann Nepomuk Hummel}
# at the end of is_composer Wolfgang Amadeus Mozart Q254 has influenced {Barbara Ployer, Thomas Attwood, Franz Xaver Süßmayr, Ignaz von Seyfried, Johann Nepomuk Hummel}
# Wolfgang Amadeus Mozart is the composer number 16 found in Richard Wagner's page
# Erreur sur le nom il s'apparente à un
# Erreur sur le nom l'influence de Bach[réf
# Erreur sur le nom de son L'Art de la fugue
# at the end of is_composer Johann Ludwig Krebs Q704174 has influenced set()
# Bach {Johann Ludwig Krebs}
# at the end of is_composer Bach Q1339 has influenced {Johann Ludwig Krebs}
# Bach is the composer number 17 found in Richard Wagner's page
# Gluck set()
# at the end of is_composer Gluck Q130759 has influenced set()
# Gluck is the composer number 18 found in Richard Wagner's page
# Erreur sur le nom qu'employer
# Erreur sur le nom même de Haydn[réf
# at the end of is_composer René Leibowitz Q966373 has influenced set()
# at the end of is_composer John Cage Q180727 has influenced set()
# Arnold Schönberg {René Leibowitz, John Cage}
# at the end of is_composer Arnold Schönberg Q154770 has influenced {René Leibowitz, John Cage}
# Arnold Schönberg is the composer number 19 found in Richard Wagner's page
# Erreur sur le nom Seul Schönberg
# at the end of is_composer Allan Pettersson Q183359 has influenced set()
# René Leibowitz {Allan Pettersson}
# at the end of is_composer René Leibowitz Q966373 has influenced {Allan Pettersson}
# René Leibowitz is the composer number 20 found in Richard Wagner's page
# Anton Bruckner set()
# at the end of is_composer Anton Bruckner Q81752 has influenced set()
# Anton Bruckner is the composer number 21 found in Richard Wagner's page
# at the end of is_composer Hugo Wolf Q215747 has influenced set() no one since no pupil was found
# Hugo Wolf is the composer number 22 found in Richard Wagner's page
# Gustav Mahler set()
# at the end of is_composer Gustav Mahler Q7304 has influenced set()
# Gustav Mahler is the composer number 23 found in Richard Wagner's page
# at the end of is_composer Richard Strauss Q13894 has influenced set() no one since no pupil was found
# Richard Strauss is the composer number 24 found in Richard Wagner's page
# Karol Szymanowski set()
# at the end of is_composer Karol Szymanowski Q295400 has influenced set()
# Karol Szymanowski is the composer number 25 found in Richard Wagner's page
# Erreur sur le nom vœu de voir l'entrée des spectacles de théâtre
# Erreur sur le nom compris aux yeux
# at the end of is_composer Giacomo Meyerbeer Q105237 has influenced set() no one since no pupil was found
# Giacomo Meyerbeer is the composer number 26 found in Richard Wagner's page
# at the end of is_composer Charles Edward Horsley Q5077278 has influenced set()
# Felix Mendelssohn {Charles Edward Horsley}
# at the end of is_composer Felix Mendelssohn Q46096 has influenced {Charles Edward Horsley}
# Felix Mendelssohn is the composer number 27 found in Richard Wagner's page
# Erreur sur le nom attire peu l'attention
# Erreur sur le nom juifs eux-mêmes[7
# Erreur sur le nom d'orchestre Hermann Levi
# Erreur sur le nom mais il renonça finalement
# Theodor W. Adorno set()
# at the end of is_composer Theodor W. Adorno Q152388 has influenced set()
# Theodor W. Adorno is the composer number 28 found in Richard Wagner's page
# at the end of is_composer Joseph Rubinstein Q3185601 has influenced set() no one since no pupil was found
# Joseph Rubinstein is the composer number 29 found in Richard Wagner's page
# Erreur sur le nom Bayreuth allait
# Erreur sur le nom ont déclenché les plus
# Erreur sur le nom même quitté la salle
# Erreur sur le nom wagnérienne israélienne
# Erreur sur le nom Phantasiestück
# Erreur sur le nom Ouvertüre zu R. Wagners Tannhäuser
# Erreur sur le nom Pilgerchor aus Tannhäuser
# Erreur sur le nom Feierlicher Marsch
# at the end of is_composer Maurice Ravel Q1178 has influenced set()
# at the end of is_composer Lucien Garban Q16635752 has influenced set()
# at the end of is_composer George Enescu Q77177 has influenced set()
# Gabriel Fauré {George Enescu, Maurice Ravel, Lucien Garban}
# at the end of is_composer Gabriel Fauré Q104919 has influenced {George Enescu, Maurice Ravel, Lucien Garban}
# Gabriel Fauré is the composer number 30 found in Richard Wagner's page
# André Messager set()
# at the end of is_composer André Messager Q457645 has influenced set()
# André Messager is the composer number 31 found in Richard Wagner's page
# Erreur sur le nom favoris de l'Anneau des Nibelung de Richard Wagner
# at the end of is_composer Peter Schickele Q1354646 has influenced set() no one since no pupil was found
# Peter Schickele is the composer number 32 found in Richard Wagner's page
# at the end of is_composer Oscar Straus Q206667 has influenced set() no one since no pupil was found
# Oscar Straus is the composer number 33 found in Richard Wagner's page
# Erreur sur le nom opérette burlesque
# at the end of is_composer Felicitas Kukuck Q1403077 has influenced set()
# at the end of is_composer Ulysses Kay Q463708 has influenced set()
# at the end of is_composer Lukas Foss Q213709 has influenced set()
# at the end of is_composer Paul Fetler Q3898052 has influenced set()
# at the end of is_composer Olga Gorelli Q7086570 has influenced set()
# Paul Hindemith {Felicitas Kukuck, Paul Fetler, Olga Gorelli, Lukas Foss, Ulysses Kay}
# at the end of is_composer Paul Hindemith Q57244 has influenced {Felicitas Kukuck, Paul Fetler, Olga Gorelli, Lukas Foss, Ulysses Kay}
# Paul Hindemith is the composer number 34 found in Richard Wagner's page
# Erreur sur le nom mauvais orchestre de station
# Erreur sur le nom parodie de l'opéra de Wagner
# Erreur sur le nom livret de Wagner
# Erreur sur le nom Paraphrase de concert sur l'Ouverture de Tannhäuser
# Alain Bonardi
# Erreur sur le nom Fünf Gedichte von Mathilde Wesendonck
# Erreur sur le nom Tannhäuser
# Gustave Bourgogne
# Erreur sur le nom Parsifal
# Rogelio de Esguquiza
# at the end of is_composer Giuseppe Becce Q367427 has influenced set() no one since no pupil was found
# Giuseppe Becce is the composer number 35 found in Richard Wagner's page
# at the end of is_composer Charlie Chaplin Q882 has influenced set() no one since no pupil was found
# Charlie Chaplin is the composer number 36 found in Richard Wagner's page
# Erreur sur le nom parodie d'opéra de Richard Wagner
# at the end of is_composer Luis Buñuel Q51545 has influenced set() no one since no pupil was found
# Luis Buñuel is the composer number 37 found in Richard Wagner's page
# Erreur sur le nom elle apparaît aussi
# at the end of is_composer Bernard Herrmann Q296804 has influenced set() no one since no pupil was found
# Bernard Herrmann is the composer number 38 found in Richard Wagner's page
# Erreur sur le nom de Sarah Zeitgeist
# at the end of is_composer Erich Wolfgang Korngold Q313371 has influenced set() no one since no pupil was found
# Erich Wolfgang Korngold is the composer number 39 found in Richard Wagner's page
# at the end of is_composer Max Steiner Q350704 has influenced set() no one since no pupil was found
# Max Steiner is the composer number 40 found in Richard Wagner's page
# Erreur sur le nom de la planète Mercure[67
# at the end of is_composer Martin Gregor-Dellin Q1248115 has influenced set() no one since no pupil was found
# Martin Gregor-Dellin is the composer number 41 found in Richard Wagner's page
# Erreur sur le nom Jean-Jacques Becquet
# Erreur sur le nom de Richard Wagner et de quatre eaux-fortes
# Erreur sur le nom musicales de Richard Wagner[modifier
# Erreur sur le nom de Martial Hulot
# Erreur sur le nom Nicolas Crapanne
# Erreur sur le nom Avec Hans von Bülow
# Erreur sur le nom Avec Joseph Arthur de Gobineau
# Erreur sur le nom librairie Nizet
# Erreur sur le nom Correspondance R.W. - F.L.
# no valid birth date for trad.
# no valid death date for trad.
# at the end of is_composer trad. Q56260622 has influenced set() no one since no pupil was found
# trad. is the composer number 42 found in Richard Wagner's page
# Erreur sur le nom J. Lacant
# Erreur sur le nom choix de Blandine Ollivier
# Erreur sur le nom Avec Minna Wagner
# Erreur sur le nom Alexandre Duncker
# Erreur sur le nom Avec Charles Nuitter
# Erreur sur le nom Romain Feist et
# Erreur sur le nom Avec Friedrich Nietzsche
# Erreur sur le nom Elizabeth Foerster-Nietzsche
# Erreur sur le nom Avec Friedrich Nietzsche
# Erreur sur le nom Correspondance Nietzsche - Wagner
# Erreur sur le nom Élisabeth Brisson et
# Erreur sur le nom Découvrir Wagner
# Erreur sur le nom Docteur Cabanès
# Erreur sur le nom seront passés
# Erreur sur le nom Aedam Musicae
# at the end of is_composer Roger Pénau Q16222679 has influenced set()
# at the end of is_composer Raoul Laparra Q2131266 has influenced set()
# at the end of is_composer Noël Gallon Q1934922 has influenced set()
# at the end of is_composer Francis Casadesus Q1441433 has influenced set()
# Albert Lavignac {Roger Pénau, Noël Gallon, Raoul Laparra, Francis Casadesus}
# at the end of is_composer Albert Lavignac Q1934522 has influenced {Roger Pénau, Noël Gallon, Raoul Laparra, Francis Casadesus}
# Albert Lavignac is the composer number 43 found in Richard Wagner's page
# Erreur sur le nom Adef-Albatros
# no valid death date for Christophe Looten
# at the end of is_composer Christophe Looten Q1086362 has influenced set() no one since no pupil was found
# Christophe Looten is the composer number 44 found in Richard Wagner's page
# Erreur sur le nom Éditions Musica-nova
# Erreur sur le nom tête de Richard Wagner
# Erreur sur le nom Essai sur l'infidélité
# Erreur sur le nom Christian Bourgeois Éditeur
# Erreur sur le nom essai de poïétique
# Erreur sur le nom querelles de Richard Wagner
# Erreur sur le nom Wolf Siegfried Wagner[70
# L. van Beethoven set()
# at the end of is_composer L. van Beethoven Q255 has influenced set()
# L. van Beethoven is the composer number 45 found in Richard Wagner's page
# Erreur sur le nom Pariser Musikleben
# Erreur sur le nom Les Voyageurs de l'Or
# Erreur sur le nom Hilan Warshaw
# Erreur sur le nom d'Olivier Teitgen
# Erreur sur le nom de Bayreuth
# Liens externes[modifier
# Erreur sur le nom Richard Wagner de Marseille Provence
# Erreur sur le nom Entretien de Jacques De Decker
# Erreur sur le nom IdRef LCCN
# Erreur sur le nom CiNii Espagne
# Erreur sur le nom Britannica Brockhaus Den
# Erreur sur le nom Catalana Hrvatska
# Erreur sur le nom Nationalencyklopedin Store
# Erreur sur le nom Treccani Universalis
# Ressources
# Erreur sur le nom Comic Vine
# Notes
# Erreur sur le nom Découvrir Wagner
# Erreur sur le nom Hilan Warshaw
# Erreur sur le nom ↑
# Erreur sur le nom ↑
# at the end of is_composer Ernest Newman Q1356476 has influenced set() no one since no pupil was found
# Ernest Newman is the composer number 46 found in Richard Wagner's page
# at the end of is_composer ↑ Manfred Kelkel Q20902193 has influenced set() no one since no pupil was found
# ↑ Manfred Kelkel is the composer number 47 found in Richard Wagner's page
# no valid death date for Alan Walker
# at the end of is_composer Alan Walker Q21808729 has influenced set() no one since no pupil was found
# Alan Walker is the composer number 48 found in Richard Wagner's page
# Erreur sur le nom ↑
# Erreur sur le nom ↑
# Erreur sur le nom fort vivante
# at the end of is_composer Henry Lemoine Q1606982 has influenced set() no one since no pupil was found
# Henry Lemoine is the composer number 49 found in Richard Wagner's page
# Erreur sur le nom détaché de Wagner
# at the end of is_composer ↑ Serge Gut Q16266889 has influenced set() no one since no pupil was found
# ↑ Serge Gut is the composer number 50 found in Richard Wagner's page
# Erreur sur le nom Karl Leich Galland
# at the end of is_composer Eugène Diaz Q28541722 has influenced set()
# at the end of is_composer Samuel David Q2218144 has influenced set()
# at the end of is_composer Victor Massé Q1382004 has influenced set()
# at the end of is_composer Renaud de Vilbac Q1065884 has influenced set()
# at the end of is_composer Jean-Baptiste Weckerlin Q934876 has influenced set()
# at the end of is_composer François Bazin Q633817 has influenced set()
# at the end of is_composer Antoine-François Marmontel Q586181 has influenced set()
# at the end of is_composer Adolphe Danhauser Q365709 has influenced set()
# Fromental Halévy {Victor Massé, Renaud de Vilbac, Adolphe Danhauser, Antoine-François Marmontel, Jean-Baptiste Weckerlin, François Bazin, Eugène Diaz, Samuel David}
# at the end of is_composer Fromental Halévy Q313917 has influenced {Victor Massé, Renaud de Vilbac, Adolphe Danhauser, Antoine-François Marmontel, Jean-Baptiste Weckerlin, François Bazin, Eugène Diaz, Samuel David}
# Fromental Halévy is the composer number 51 found in Richard Wagner's page
# Erreur sur le nom ↑
# Erreur sur le nom Être wagnérien
# Erreur sur le nom ↑
# at the end of is_composer Gustave Samazeuilh Q447590 has influenced set() no one since no pupil was found
# Gustave Samazeuilh is the composer number 52 found in Richard Wagner's page
# Erreur sur le nom Querelles de Richard Wagner
# Erreur sur le nom ↑ Friedlind Wagner
# at the end of is_composer Wolfgang Wagner Q60452 has influenced set() no one since no pupil was found
# Wolfgang Wagner is the composer number 53 found in Richard Wagner's page
# at the end of is_composer de Wieland Wagner Q60465 has influenced set() no one since no pupil was found
# de Wieland Wagner is the composer number 54 found in Richard Wagner's page
# no valid death date for ↑ Gottfried Wagner
# at the end of is_composer ↑ Gottfried Wagner Q68439 has influenced set() no one since no pupil was found
# ↑ Gottfried Wagner is the composer number 55 found in Richard Wagner's page
# no valid death date for Katharina Wagner
# at the end of is_composer Katharina Wagner Q63907 has influenced set() no one since no pupil was found
# Katharina Wagner is the composer number 56 found in Richard Wagner's page
# Erreur sur le nom mMaîtres de la chapelle de Dresde
# at the end of is_composer Antonio Scandello Q466841 has influenced set() no one since no pupil was found
# Antonio Scandello is the composer number 57 found in Richard Wagner's page
# at the end of is_composer Giovanni Battista Pinello Q834087 has influenced set() no one since no pupil was found
# Giovanni Battista Pinello is the composer number 58 found in Richard Wagner's page
# at the end of is_composer Rogier Michael Q507030 has influenced set() no one since no pupil was found
# Rogier Michael is the composer number 59 found in Richard Wagner's page
# at the end of is_composer Johann Wilhelm Furchheim Q323768 has influenced set()
# at the end of is_composer David Pohle Q320295 has influenced set()
# at the end of is_composer Johann Vierdanck Q69400 has influenced set()
# at the end of is_composer Philipp Stolle Q7184697 has influenced set()
# at the end of is_composer Anton Colander Q4775711 has influenced set()
# at the end of is_composer Johann Nauwach Q1695639 has influenced set()
# at the end of is_composer Johann Jakob Löwe Q1694815 has influenced set()
# at the end of is_composer Carlo Farina Q606273 has influenced set()
# Heinrich Schütz {David Pohle, Philipp Stolle, Anton Colander, Johann Nauwach, Johann Vierdanck, Carlo Farina, Johann Jakob Löwe, Johann Wilhelm Furchheim}
# at the end of is_composer Heinrich Schütz Q153643 has influenced {David Pohle, Philipp Stolle, Anton Colander, Johann Nauwach, Johann Vierdanck, Carlo Farina, Johann Jakob Löwe, Johann Wilhelm Furchheim}
# Heinrich Schütz is the composer number 60 found in Richard Wagner's page
# Vincenzo Albrici set()
# at the end of is_composer Vincenzo Albrici Q543891 has influenced set()
# Vincenzo Albrici is the composer number 61 found in Richard Wagner's page
# at the end of is_composer Giovanni Andrea Angelini Bontempi Q875506 has influenced set() no one since no pupil was found
# Giovanni Andrea Angelini Bontempi is the composer number 62 found in Richard Wagner's page
# at the end of is_composer Nicolaus Adam Strungk Q463939 has influenced set() no one since no pupil was found
# Nicolaus Adam Strungk is the composer number 63 found in Richard Wagner's page
# Antonio Lotti set()
# at the end of is_composer Antonio Lotti Q168345 has influenced set()
# Antonio Lotti is the composer number 64 found in Richard Wagner's page
# at the end of is_composer Johann David Heinichen Q506627 has influenced set() no one since no pupil was found
# Johann David Heinichen is the composer number 65 found in Richard Wagner's page
# at the end of is_composer Johann Adolph Hasse Q164732 has influenced set() no one since no pupil was found
# Johann Adolph Hasse is the composer number 66 found in Richard Wagner's page
# at the end of is_composer Johann Gottlieb Naumann Q213927 has influenced set() no one since no pupil was found
# Johann Gottlieb Naumann is the composer number 67 found in Richard Wagner's page
# Ferdinando Paer set()
# at the end of is_composer Ferdinando Paer Q533022 has influenced set()
# Ferdinando Paer is the composer number 68 found in Richard Wagner's page
# Francesco Morlacchi set()
# at the end of is_composer Francesco Morlacchi Q571408 has influenced set()
# Francesco Morlacchi is the composer number 69 found in Richard Wagner's page
# at the end of is_composer Hermann Berens Q570444 has influenced set()
# Carl Gottlieb Reißiger {Hermann Berens}
# at the end of is_composer Carl Gottlieb Reißiger Q213894 has influenced {Hermann Berens}
# Carl Gottlieb Reißiger is the composer number 70 found in Richard Wagner's page
# at the end of is_composer Arthur O'Leary Q17984779 has influenced set()
# Julius Rietz {Arthur O'Leary}
# at the end of is_composer Julius Rietz Q63745 has influenced {Arthur O'Leary}
# Julius Rietz is the composer number 71 found in Richard Wagner's page
# Franz Wüllner set()
# at the end of is_composer Franz Wüllner Q819749 has influenced set()
# Franz Wüllner is the composer number 72 found in Richard Wagner's page
# at the end of is_composer Ernst von Schuch Q79029 has influenced set() no one since no pupil was found
# Ernst von Schuch is the composer number 73 found in Richard Wagner's page
# Fritz Reiner set()
# at the end of is_composer Fritz Reiner Q364179 has influenced set()
# Fritz Reiner is the composer number 74 found in Richard Wagner's page
# Karl Böhm set()
# at the end of is_composer Karl Böhm Q84241 has influenced set()
# Karl Böhm is the composer number 75 found in Richard Wagner's page
# Giuseppe Sinopoli set()
# at the end of is_composer Giuseppe Sinopoli Q316903 has influenced set()
# Giuseppe Sinopoli is the composer number 76 found in Richard Wagner's page
# Erreur sur le nom Ossian
# Nationalisme
# Erreur sur le nom Christian Andersen
# Achim von Arnim
# at the end of is_composer Bettina von Arnim Q57236 has influenced set() no one since no pupil was found
# Bettina von Arnim is the composer number 77 found in Richard Wagner's page
# Erreur sur le nom Aloysius Bertrand
# William Blake
#
# Erreur sur le nom Clemens Brentano
# William Cullen Bryant
# at the end of is_composer Johann Wolfgang von Goethe
#  Q5879 has influenced set() no one since no pupil was found
# Johann Wolfgang von Goethe
#  is the composer number 78 found in Richard Wagner's page
# at the end of is_composer Amadeus Hoffmann Q150471 has influenced set() no one since no pupil was found
# Amadeus Hoffmann is the composer number 79 found in Richard Wagner's page
# Erreur sur le nom Mariano José de Larra
# Giacomo Leopardi
#
# Erreur sur le nom Karel Hynek Mácha
# Antoni Malczewski
# Erreur sur le nom Alessandro Manzoni
# Adam Mickiewicz
# Erreur sur le nom Gérard de Nerval
# Charles Nodier
# Erreur sur le nom Alexandre Pouchkine
# George Sand
# Friedrich Schiller
# Erreur sur le nom Juliusz Słowacki
# Germaine de Staël
# Stendhal
# Erreur sur le nom Alfred de Vigny
# William Wordsworth
#
# Erreur sur le nom Adolphe Adam
# Isaac Albéniz
# Charles-Valentin Alkan
# at the end of is_composer Théodore Akimenko Q2000816 has influenced set()
# Mili Balakirev {Théodore Akimenko}
# at the end of is_composer Mili Balakirev Q185040 has influenced {Théodore Akimenko}
# Mili Balakirev is the composer number 80 found in Richard Wagner's page
# Erreur sur le nom Louise Bertin
# Franz Berwald
# Georges Bizet
# at the end of is_composer Charlotte Sohy Q2399157 has influenced set()
# Mel Bonis {Charlotte Sohy}
# at the end of is_composer Mel Bonis Q467452 has influenced {Charlotte Sohy}
# Mel Bonis is the composer number 81 found in Richard Wagner's page
# at the end of is_composer Alexandre Borodine
#  Q164004 has influenced set() no one since no pupil was found
# Alexandre Borodine
#  is the composer number 82 found in Richard Wagner's page
# Erreur sur le nom Luigi Cherubini
# Frédéric Chopin
# at the end of is_composer Félicien David Q951933 has influenced set() no one since no pupil was found
# Félicien David is the composer number 83 found in Richard Wagner's page
# Erreur sur le nom Ferdinand David
# Gaetano Donizetti
# Erreur sur le nom Antonín Dvořák
# John Field
# at the end of is_composer Mikhaïl Glinka Q181885 has influenced set() no one since no pupil was found
# Mikhaïl Glinka is the composer number 84 found in Richard Wagner's page
# at the end of is_composer José Miró i Anoria Q20004429 has influenced set()
# at the end of is_composer Camille-Marie Stamaty Q1029284 has influenced set()
# at the end of is_composer Ambroise Thomas Q297717 has influenced set()
# Friedrich Kalkbrenner {Ambroise Thomas, Camille-Marie Stamaty, José Miró i Anoria}
# at the end of is_composer Friedrich Kalkbrenner Q170270 has influenced {Ambroise Thomas, Camille-Marie Stamaty, José Miró i Anoria}
# Friedrich Kalkbrenner is the composer number 85 found in Richard Wagner's page
# at the end of is_composer Emilie Mayer Q447851 has influenced set()
# Carl Loewe {Emilie Mayer}
# at the end of is_composer Carl Loewe Q158899 has influenced {Emilie Mayer}
# Carl Loewe is the composer number 86 found in Richard Wagner's page
# Erreur sur le nom Santiago Masarnau Fernández
# Étienne-Nicolas Méhul
# Fanny Mendelssohn set()
# at the end of is_composer Fanny Mendelssohn Q57286 has influenced set()
# Fanny Mendelssohn is the composer number 87 found in Richard Wagner's page
# at the end of is_composer Modeste Moussorgski Q132682 has influenced set() no one since no pupil was found
# Modeste Moussorgski is the composer number 88 found in Richard Wagner's page
# Erreur sur le nom Louis Niedermeyer
# Ignaz Moscheles
# Niccolò Paganini
#
# at the end of is_composer Hector Berlioz Q1151 has influenced set()
# at the end of is_composer Alphonse Leduc Q50333026 has influenced set()
# at the end of is_composer Eugène Sauzay Q4426800 has influenced set()
# Antoine Reicha
#  {Eugène Sauzay, Hector Berlioz, Alphonse Leduc}
# at the end of is_composer Antoine Reicha
#  Q311387 has influenced {Eugène Sauzay, Hector Berlioz, Alphonse Leduc}
# Antoine Reicha
#  is the composer number 89 found in Richard Wagner's page
# Erreur sur le nom Gioachino Rossini
# Pablo de Sarasate
# Franz Schubert
# Clara Schumann set()
# at the end of is_composer Clara Schumann Q132232 has influenced set()
# Clara Schumann is the composer number 90 found in Richard Wagner's page
# Robert Schumann set()
# at the end of is_composer Robert Schumann Q7351 has influenced set()
# Robert Schumann is the composer number 91 found in Richard Wagner's page
# Erreur sur le nom Bedřich Smetana
# Gaspare Spontini
# Erreur sur le nom Francisco Tárrega
# Piotr
# at the end of is_composer Virginia Gabriel Q7934272 has influenced set()
# Sigismund Thalberg {Virginia Gabriel}
# at the end of is_composer Sigismund Thalberg Q347871 has influenced {Virginia Gabriel}
# Sigismund Thalberg is the composer number 92 found in Richard Wagner's page
# at the end of is_composer Giuseppe Verdi
# Jan Q7317 has influenced set() no one since no pupil was found
# Giuseppe Verdi
# Jan is the composer number 93 found in Richard Wagner's page
# Erreur sur le nom Johann Gottlieb Fichte
# Johann Wolfgang von Goethe
# Erreur sur le nom William Blake
# Carl Blechen
#
# Erreur sur le nom Carl Gustav Carus
# Thomas Cole
#
# Erreur sur le nom Delacroix
# École de Düsseldorf
# Carl
# Erreur sur le nom Caspar David Friedrich
# Johann Heinrich Füssli
# Erreur sur le nom John Martin
# Piotr Michałowski
# Mouvement
# Erreur sur le nom Carl Rottmann
# Philipp
# Erreur sur le nom de symphonieMusicographeFamille WagnerAutobiographe
# Erreur sur le nom Rechercher
#
#
#
#
#
#
#
#
#
# Basculer
# 1st composer of this page : Richard Wagner Q1511 {Gudrun Wagner, Marie d'Agoult, Franz Liszt, Siegfried Wagner, Claude Debussy}
# db:1813
# dd:1883
# added Siegfried Wagner to Richard Wagner
# added Marie d'Agoult to Richard Wagner in the new way
# added Richard Wagner to Marie d'Agoult
# added Gudrun Wagner to Richard Wagner
# added Franz Liszt to Richard Wagner in the new way
# added Richard Wagner to Franz Liszt
# added Richard Wagner to Franz Schubert
# added Claude Debussy to Richard Wagner in the new way
# added Richard Wagner to Claude Debussy
# added Hermann Levi to Richard Wagner in the new way
# added Richard Wagner to Hermann Levi
# added Cosima Liszt
#
#
#  to Richard Wagner in the new way
# added Richard Wagner to Cosima Liszt
#
#
#
# added Friedrich Nietzsche to Richard Wagner in the new way
# added Richard Wagner to Friedrich Nietzsche
# added Richard Wagner to Carl Maria von Weber
# added Richard Wagner to Hans Sachs
# added Vincent d'Indy to Richard Wagner in the new way
# added Richard Wagner to Vincent d'Indy
# added l'orchestre joue to Richard Wagner
# added Wilhelm Furtwängler to Richard Wagner
# added Jacques Chailley to Richard Wagner
# added Richard Wagner to Wolfgang Amadeus Mozart
# added Richard Wagner to Bach
# added Richard Wagner to Gluck
# added Arnold Schönberg to Richard Wagner
# added René Leibowitz to Richard Wagner
# added Anton Bruckner to Richard Wagner in the new way
# added Richard Wagner to Anton Bruckner
# added Hugo Wolf to Richard Wagner in the new way
# added Richard Wagner to Hugo Wolf
# added Gustav Mahler to Richard Wagner in the new way
# added Richard Wagner to Gustav Mahler
# added Richard Strauss to Richard Wagner
# added Karol Szymanowski to Richard Wagner
# added Giacomo Meyerbeer to Richard Wagner in the new way
# added Richard Wagner to Giacomo Meyerbeer
# added Felix Mendelssohn to Richard Wagner in the new way
# added Richard Wagner to Felix Mendelssohn
# added Theodor W. Adorno to Richard Wagner
# added Joseph Rubinstein to Richard Wagner in the new way
# added Richard Wagner to Joseph Rubinstein
# added Gabriel Fauré to Richard Wagner in the new way
# added Richard Wagner to Gabriel Fauré
# added André Messager to Richard Wagner in the new way
# added Richard Wagner to André Messager
# added Peter Schickele to Richard Wagner
# added Oscar Straus to Richard Wagner
# added Paul Hindemith to Richard Wagner
# added Giuseppe Becce to Richard Wagner
# added Charlie Chaplin to Richard Wagner
# added Luis Buñuel to Richard Wagner
# added Bernard Herrmann to Richard Wagner
# added Erich Wolfgang Korngold to Richard Wagner
# added Max Steiner to Richard Wagner
# added Martin Gregor-Dellin to Richard Wagner
# added trad. to Richard Wagner
# added Richard Wagner to trad.
# added Albert Lavignac to Richard Wagner in the new way
# added Richard Wagner to Albert Lavignac
# added Christophe Looten to Richard Wagner
# added Richard Wagner to L. van Beethoven
# added Ernest Newman to Richard Wagner
# added ↑ Manfred Kelkel to Richard Wagner
# added Alan Walker to Richard Wagner
# added Henry Lemoine to Richard Wagner in the new way
# added Richard Wagner to Henry Lemoine
# added ↑ Serge Gut to Richard Wagner
# added Fromental Halévy to Richard Wagner in the new way
# added Richard Wagner to Fromental Halévy
# added Gustave Samazeuilh to Richard Wagner
# added Wolfgang Wagner to Richard Wagner
# added de Wieland Wagner to Richard Wagner
# added ↑ Gottfried Wagner to Richard Wagner
# added Katharina Wagner to Richard Wagner
# added Richard Wagner to Antonio Scandello
# added Richard Wagner to Giovanni Battista Pinello
# added Richard Wagner to Rogier Michael
# added Richard Wagner to Heinrich Schütz
# added Richard Wagner to Vincenzo Albrici
# added Richard Wagner to Giovanni Andrea Angelini Bontempi
# added Richard Wagner to Nicolaus Adam Strungk
# added Richard Wagner to Antonio Lotti
# added Richard Wagner to Johann David Heinichen
# added Richard Wagner to Johann Adolph Hasse
# added Richard Wagner to Johann Gottlieb Naumann
# added Ferdinando Paer to Richard Wagner in the new way
# added Richard Wagner to Ferdinando Paer
# added Francesco Morlacchi to Richard Wagner in the new way
# added Richard Wagner to Francesco Morlacchi
# added Carl Gottlieb Reißiger to Richard Wagner in the new way
# added Richard Wagner to Carl Gottlieb Reißiger
# added Julius Rietz to Richard Wagner in the new way
# added Richard Wagner to Julius Rietz
# added Franz Wüllner to Richard Wagner in the new way
# added Richard Wagner to Franz Wüllner
# added Ernst von Schuch to Richard Wagner in the new way
# added Richard Wagner to Ernst von Schuch
# added Fritz Reiner to Richard Wagner
# added Karl Böhm to Richard Wagner
# added Giuseppe Sinopoli to Richard Wagner
# added Bettina von Arnim to Richard Wagner in the new way
# added Richard Wagner to Bettina von Arnim
# added Richard Wagner to Johann Wolfgang von Goethe
#
# added Richard Wagner to Amadeus Hoffmann
# added Mili Balakirev to Richard Wagner in the new way
# added Richard Wagner to Mili Balakirev
# added Mel Bonis to Richard Wagner in the new way
# added Richard Wagner to Mel Bonis
# added Alexandre Borodine
#  to Richard Wagner in the new way
# added Richard Wagner to Alexandre Borodine
#
# added Félicien David to Richard Wagner in the new way
# added Richard Wagner to Félicien David
# added Mikhaïl Glinka to Richard Wagner in the new way
# added Richard Wagner to Mikhaïl Glinka
# added Friedrich Kalkbrenner to Richard Wagner in the new way
# added Richard Wagner to Friedrich Kalkbrenner
# added Carl Loewe to Richard Wagner in the new way
# added Richard Wagner to Carl Loewe
# added Fanny Mendelssohn to Richard Wagner in the new way
# added Richard Wagner to Fanny Mendelssohn
# added Modeste Moussorgski to Richard Wagner in the new way
# added Richard Wagner to Modeste Moussorgski
# added Antoine Reicha
#  to Richard Wagner in the new way
# added Richard Wagner to Antoine Reicha
#
# added Clara Schumann to Richard Wagner in the new way
# added Richard Wagner to Clara Schumann
# added Robert Schumann to Richard Wagner in the new way
# added Richard Wagner to Robert Schumann
# added Sigismund Thalberg to Richard Wagner in the new way
# added Richard Wagner to Sigismund Thalberg
# added Giuseppe Verdi
# Jan to Richard Wagner in the new way
# added Richard Wagner to Giuseppe Verdi
# Jan
# Richard Wagner has influenced {Antoine Reicha
# , Cosima Liszt
#
#
# , Fromental Halévy, Christophe Looten, Claude Debussy, Siegfried Wagner, Franz Liszt, Luis Buñuel, Erich Wolfgang Korngold, Vincent d'Indy, Mili Balakirev, Oscar Straus, trad., ↑ Serge Gut, Robert Schumann, Anton Bruckner, Ernest Newman, Ferdinando Paer, René Leibowitz, Martin Gregor-Dellin, Siegfried Wagner, Paul Hindemith, Franz Liszt, Richard Strauss, l'orchestre joue, ↑ Manfred Kelkel, Peter Schickele, Giuseppe Becce, Charlie Chaplin, Katharina Wagner, Jacques Chailley, de Wieland Wagner, ↑ Gottfried Wagner, Marie d'Agoult, Marie d'Agoult, Franz Wüllner, Giacomo Meyerbeer, Alexandre Borodine
# , Gudrun Wagner, Albert Lavignac, Ernst von Schuch, Karl Böhm, Wilhelm Furtwängler, Mikhaïl Glinka, Felix Mendelssohn, Giuseppe Verdi
# Jan, Carl Gottlieb Reißiger, Max Steiner, Fanny Mendelssohn, Theodor W. Adorno, Alan Walker, Wolfgang Wagner, Julius Rietz, Gudrun Wagner, Félicien David, Gustave Samazeuilh, Gabriel Fauré, Friedrich Nietzsche, Francesco Morlacchi, Mel Bonis, Henry Lemoine, Giuseppe Sinopoli, Friedrich Kalkbrenner, Clara Schumann, Joseph Rubinstein, Bettina von Arnim, Carl Loewe, Hugo Wolf, André Messager, Gustav Mahler, Sigismund Thalberg, Modeste Moussorgski, Hermann Levi, Claude Debussy, Karol Szymanowski, Bernard Herrmann, Arnold Schönberg, Fritz Reiner}
# in build_graph_from_dict Richard Wagner has influenced {Antoine Reicha
# , Cosima Liszt
#
#
# , Fromental Halévy, Christophe Looten, Claude Debussy, Siegfried Wagner, Franz Liszt, Luis Buñuel, Erich Wolfgang Korngold, Vincent d'Indy, Mili Balakirev, Oscar Straus, trad., ↑ Serge Gut, Robert Schumann, Anton Bruckner, Ernest Newman, Ferdinando Paer, René Leibowitz, Martin Gregor-Dellin, Siegfried Wagner, Paul Hindemith, Franz Liszt, Richard Strauss, l'orchestre joue, ↑ Manfred Kelkel, Peter Schickele, Giuseppe Becce, Charlie Chaplin, Katharina Wagner, Jacques Chailley, de Wieland Wagner, ↑ Gottfried Wagner, Marie d'Agoult, Marie d'Agoult, Franz Wüllner, Giacomo Meyerbeer, Alexandre Borodine
# , Gudrun Wagner, Albert Lavignac, Ernst von Schuch, Karl Böhm, Wilhelm Furtwängler, Mikhaïl Glinka, Felix Mendelssohn, Giuseppe Verdi
# Jan, Carl Gottlieb Reißiger, Max Steiner, Fanny Mendelssohn, Theodor W. Adorno, Alan Walker, Wolfgang Wagner, Julius Rietz, Gudrun Wagner, Félicien David, Gustave Samazeuilh, Gabriel Fauré, Friedrich Nietzsche, Francesco Morlacchi, Mel Bonis, Henry Lemoine, Giuseppe Sinopoli, Friedrich Kalkbrenner, Clara Schumann, Joseph Rubinstein, Bettina von Arnim, Carl Loewe, Hugo Wolf, André Messager, Gustav Mahler, Sigismund Thalberg, Modeste Moussorgski, Hermann Levi, Claude Debussy, Karol Szymanowski, Bernard Herrmann, Arnold Schönberg, Fritz Reiner}
# added Antoine Reicha
#  to Richard Wagner
# added Cosima Liszt
#
#
#  to Richard Wagner
# added Fromental Halévy to Richard Wagner
# added Christophe Looten to Richard Wagner
# added Claude Debussy to Richard Wagner
# added Siegfried Wagner to Richard Wagner
# added Franz Liszt to Richard Wagner
# added Luis Buñuel to Richard Wagner
# added Erich Wolfgang Korngold to Richard Wagner
# added Vincent d'Indy to Richard Wagner
# added Mili Balakirev to Richard Wagner
# added Oscar Straus to Richard Wagner
# added trad. to Richard Wagner
# added ↑ Serge Gut to Richard Wagner
# added Robert Schumann to Richard Wagner
# added Anton Bruckner to Richard Wagner
# added Ernest Newman to Richard Wagner
# added Ferdinando Paer to Richard Wagner
# added René Leibowitz to Richard Wagner
# added Martin Gregor-Dellin to Richard Wagner
# added Siegfried Wagner to Richard Wagner
# added Paul Hindemith to Richard Wagner
# added Franz Liszt to Richard Wagner
# added Richard Strauss to Richard Wagner
# added l'orchestre joue to Richard Wagner
# added ↑ Manfred Kelkel to Richard Wagner
# added Peter Schickele to Richard Wagner
# added Giuseppe Becce to Richard Wagner
# added Charlie Chaplin to Richard Wagner
# added Katharina Wagner to Richard Wagner
# added Jacques Chailley to Richard Wagner
# added de Wieland Wagner to Richard Wagner
# added ↑ Gottfried Wagner to Richard Wagner
# added Marie d'Agoult to Richard Wagner
# added Marie d'Agoult to Richard Wagner
# added Franz Wüllner to Richard Wagner
# added Giacomo Meyerbeer to Richard Wagner
# added Alexandre Borodine
#  to Richard Wagner
# added Gudrun Wagner to Richard Wagner
# added Albert Lavignac to Richard Wagner
# added Ernst von Schuch to Richard Wagner
# added Karl Böhm to Richard Wagner
# added Wilhelm Furtwängler to Richard Wagner
# added Mikhaïl Glinka to Richard Wagner
# added Felix Mendelssohn to Richard Wagner
# added Giuseppe Verdi
# Jan to Richard Wagner
# added Carl Gottlieb Reißiger to Richard Wagner
# added Max Steiner to Richard Wagner
# added Fanny Mendelssohn to Richard Wagner
# added Theodor W. Adorno to Richard Wagner
# added Alan Walker to Richard Wagner
# added Wolfgang Wagner to Richard Wagner
# added Julius Rietz to Richard Wagner
# added Gudrun Wagner to Richard Wagner
# added Félicien David to Richard Wagner
# added Gustave Samazeuilh to Richard Wagner
# added Gabriel Fauré to Richard Wagner
# added Friedrich Nietzsche to Richard Wagner
# added Francesco Morlacchi to Richard Wagner
# added Mel Bonis to Richard Wagner
# added Henry Lemoine to Richard Wagner
# added Giuseppe Sinopoli to Richard Wagner
# added Friedrich Kalkbrenner to Richard Wagner
# added Clara Schumann to Richard Wagner
# added Joseph Rubinstein to Richard Wagner
# added Bettina von Arnim to Richard Wagner
# added Carl Loewe to Richard Wagner
# added Hugo Wolf to Richard Wagner
# added André Messager to Richard Wagner
# added Gustav Mahler to Richard Wagner
# added Sigismund Thalberg to Richard Wagner
# added Modeste Moussorgski to Richard Wagner
# added Hermann Levi to Richard Wagner
# added Claude Debussy to Richard Wagner
# added Karol Szymanowski to Richard Wagner
# added Bernard Herrmann to Richard Wagner
# added Arnold Schönberg to Richard Wagner
# added Fritz Reiner to Richard Wagner
# in build_graph_from_dict Siegfried Wagner has influenced {Hans Knappertsbusch}
# added Hans Knappertsbusch to Siegfried Wagner
# in build_graph_from_dict Marie d'Agoult has influenced {Richard Wagner, Richard Wagner}
# added Richard Wagner to Marie d'Agoult
# added Richard Wagner to Marie d'Agoult
# in build_graph_from_dict Gudrun Wagner has influenced set()
# in build_graph_from_dict Franz Liszt has influenced {Arthur Friedheim, Richard Wagner, Carl Ludvig Hall, Eugen d'Albert, William Dayas, Bettina Walker, Eloísa D’Herbil, Julie Rivé-King, Richard Wagner, Hilda Thegerström}
# added Arthur Friedheim to Franz Liszt
# added Richard Wagner to Franz Liszt
# added Carl Ludvig Hall to Franz Liszt
# added Eugen d'Albert to Franz Liszt
# added William Dayas to Franz Liszt
# added Bettina Walker to Franz Liszt
# added Eloísa D’Herbil to Franz Liszt
# added Julie Rivé-King to Franz Liszt
# added Richard Wagner to Franz Liszt
# added Hilda Thegerström to Franz Liszt
# in build_graph_from_dict Franz Schubert has influenced {Richard Wagner, Richard Wagner}
# added Richard Wagner to Franz Schubert
# added Richard Wagner to Franz Schubert
# in build_graph_from_dict Claude Debussy has influenced {Richard Wagner, Richard Wagner, Raoul Bardac}
# added Richard Wagner to Claude Debussy
# added Richard Wagner to Claude Debussy
# added Raoul Bardac to Claude Debussy
# in build_graph_from_dict Hermann Levi has influenced {Richard Wagner}
# added Richard Wagner to Hermann Levi
# in build_graph_from_dict Cosima Liszt
#
#
#  has influenced {Richard Wagner}
# added Richard Wagner to Cosima Liszt
#
#
#
# in build_graph_from_dict Friedrich Nietzsche has influenced {Richard Wagner}
# added Richard Wagner to Friedrich Nietzsche
# in build_graph_from_dict Carl Maria von Weber has influenced {Caroline Ridderstolpe, Richard Wagner}
# added Caroline Ridderstolpe to Carl Maria von Weber
# added Richard Wagner to Carl Maria von Weber
# in build_graph_from_dict Hans Sachs has influenced {Richard Wagner}
# added Richard Wagner to Hans Sachs
# in build_graph_from_dict Vincent d'Indy has influenced {Marcel Labey, László Lajtha, Edward Shippen Barnes, Emiliana de Zubeldia, Blanche Selva, Blanche Lucas, Helena Munktell, Richard Wagner, Paul Berthier, Eugène Grassi}
# added Marcel Labey to Vincent d'Indy
# added László Lajtha to Vincent d'Indy
# added Edward Shippen Barnes to Vincent d'Indy
# added Emiliana de Zubeldia to Vincent d'Indy
# added Blanche Selva to Vincent d'Indy
# added Blanche Lucas to Vincent d'Indy
# added Helena Munktell to Vincent d'Indy
# added Richard Wagner to Vincent d'Indy
# added Paul Berthier to Vincent d'Indy
# added Eugène Grassi to Vincent d'Indy
# in build_graph_from_dict l'orchestre joue has influenced set()
# in build_graph_from_dict Wilhelm Furtwängler has influenced set()
# in build_graph_from_dict Jacques Chailley has influenced set()
# in build_graph_from_dict Wolfgang Amadeus Mozart has influenced {Barbara Ployer, Thomas Attwood, Franz Xaver Süßmayr, Ignaz von Seyfried, Johann Nepomuk Hummel, Richard Wagner}
# added Barbara Ployer to Wolfgang Amadeus Mozart
# added Thomas Attwood to Wolfgang Amadeus Mozart
# added Franz Xaver Süßmayr to Wolfgang Amadeus Mozart
# added Ignaz von Seyfried to Wolfgang Amadeus Mozart
# added Johann Nepomuk Hummel to Wolfgang Amadeus Mozart
# added Richard Wagner to Wolfgang Amadeus Mozart
# in build_graph_from_dict Bach has influenced {Johann Ludwig Krebs, Richard Wagner}
# added Johann Ludwig Krebs to Bach
# added Richard Wagner to Bach
# in build_graph_from_dict Gluck has influenced {Richard Wagner}
# added Richard Wagner to Gluck
# in build_graph_from_dict Arnold Schönberg has influenced {René Leibowitz, John Cage}
# added René Leibowitz to Arnold Schönberg
# added John Cage to Arnold Schönberg
# in build_graph_from_dict René Leibowitz has influenced {Allan Pettersson}
# added Allan Pettersson to René Leibowitz
# in build_graph_from_dict Anton Bruckner has influenced {Richard Wagner}
# added Richard Wagner to Anton Bruckner
# in build_graph_from_dict Hugo Wolf has influenced {Richard Wagner}
# added Richard Wagner to Hugo Wolf
# in build_graph_from_dict Gustav Mahler has influenced {Richard Wagner}
# added Richard Wagner to Gustav Mahler
# in build_graph_from_dict Richard Strauss has influenced set()
# in build_graph_from_dict Karol Szymanowski has influenced set()
# in build_graph_from_dict Giacomo Meyerbeer has influenced {Richard Wagner}
# added Richard Wagner to Giacomo Meyerbeer
# in build_graph_from_dict Felix Mendelssohn has influenced {Charles Edward Horsley, Richard Wagner}
# added Charles Edward Horsley to Felix Mendelssohn
# added Richard Wagner to Felix Mendelssohn
# in build_graph_from_dict Theodor W. Adorno has influenced set()
# in build_graph_from_dict Joseph Rubinstein has influenced {Richard Wagner}
# added Richard Wagner to Joseph Rubinstein
# in build_graph_from_dict Gabriel Fauré has influenced {George Enescu, Richard Wagner, Maurice Ravel, Lucien Garban}
# added George Enescu to Gabriel Fauré
# added Richard Wagner to Gabriel Fauré
# added Maurice Ravel to Gabriel Fauré
# added Lucien Garban to Gabriel Fauré
# in build_graph_from_dict André Messager has influenced {Richard Wagner}
# added Richard Wagner to André Messager
# in build_graph_from_dict Peter Schickele has influenced set()
# in build_graph_from_dict Oscar Straus has influenced set()
# in build_graph_from_dict Paul Hindemith has influenced {Felicitas Kukuck, Paul Fetler, Olga Gorelli, Lukas Foss, Ulysses Kay}
# added Felicitas Kukuck to Paul Hindemith
# added Paul Fetler to Paul Hindemith
# added Olga Gorelli to Paul Hindemith
# added Lukas Foss to Paul Hindemith
# added Ulysses Kay to Paul Hindemith
# in build_graph_from_dict Giuseppe Becce has influenced set()
# in build_graph_from_dict Charlie Chaplin has influenced set()
# in build_graph_from_dict Luis Buñuel has influenced set()
# in build_graph_from_dict Bernard Herrmann has influenced set()
# in build_graph_from_dict Erich Wolfgang Korngold has influenced set()
# in build_graph_from_dict Max Steiner has influenced set()
# in build_graph_from_dict Martin Gregor-Dellin has influenced set()
# in build_graph_from_dict trad. has influenced {Richard Wagner}
# added Richard Wagner to trad.
# in build_graph_from_dict Albert Lavignac has influenced {Noël Gallon, Roger Pénau, Richard Wagner, Francis Casadesus, Raoul Laparra}
# added Noël Gallon to Albert Lavignac
# added Roger Pénau to Albert Lavignac
# added Richard Wagner to Albert Lavignac
# added Francis Casadesus to Albert Lavignac
# added Raoul Laparra to Albert Lavignac
# in build_graph_from_dict Christophe Looten has influenced set()
# in build_graph_from_dict L. van Beethoven has influenced {Richard Wagner}
# added Richard Wagner to L. van Beethoven
# in build_graph_from_dict Ernest Newman has influenced set()
# in build_graph_from_dict ↑ Manfred Kelkel has influenced set()
# in build_graph_from_dict Alan Walker has influenced set()
# in build_graph_from_dict Henry Lemoine has influenced {Richard Wagner}
# added Richard Wagner to Henry Lemoine
# in build_graph_from_dict ↑ Serge Gut has influenced set()
# in build_graph_from_dict Fromental Halévy has influenced {Victor Massé, Renaud de Vilbac, Adolphe Danhauser, Antoine-François Marmontel, Jean-Baptiste Weckerlin, François Bazin, Eugène Diaz, Richard Wagner, Samuel David}
# added Victor Massé to Fromental Halévy
# added Renaud de Vilbac to Fromental Halévy
# added Adolphe Danhauser to Fromental Halévy
# added Antoine-François Marmontel to Fromental Halévy
# added Jean-Baptiste Weckerlin to Fromental Halévy
# added François Bazin to Fromental Halévy
# added Eugène Diaz to Fromental Halévy
# added Richard Wagner to Fromental Halévy
# added Samuel David to Fromental Halévy
# in build_graph_from_dict Gustave Samazeuilh has influenced set()
# in build_graph_from_dict Wolfgang Wagner has influenced set()
# in build_graph_from_dict de Wieland Wagner has influenced set()
# in build_graph_from_dict ↑ Gottfried Wagner has influenced set()
# in build_graph_from_dict Katharina Wagner has influenced set()
# in build_graph_from_dict Antonio Scandello has influenced {Richard Wagner}
# added Richard Wagner to Antonio Scandello
# in build_graph_from_dict Giovanni Battista Pinello has influenced {Richard Wagner}
# added Richard Wagner to Giovanni Battista Pinello
# in build_graph_from_dict Rogier Michael has influenced {Richard Wagner}
# added Richard Wagner to Rogier Michael
# in build_graph_from_dict Heinrich Schütz has influenced {David Pohle, Philipp Stolle, Anton Colander, Johann Nauwach, Johann Vierdanck, Richard Wagner, Carlo Farina, Johann Jakob Löwe, Johann Wilhelm Furchheim}
# added David Pohle to Heinrich Schütz
# added Philipp Stolle to Heinrich Schütz
# added Anton Colander to Heinrich Schütz
# added Johann Nauwach to Heinrich Schütz
# added Johann Vierdanck to Heinrich Schütz
# added Richard Wagner to Heinrich Schütz
# added Carlo Farina to Heinrich Schütz
# added Johann Jakob Löwe to Heinrich Schütz
# added Johann Wilhelm Furchheim to Heinrich Schütz
# in build_graph_from_dict Vincenzo Albrici has influenced {Richard Wagner}
# added Richard Wagner to Vincenzo Albrici
# in build_graph_from_dict Giovanni Andrea Angelini Bontempi has influenced {Richard Wagner}
# added Richard Wagner to Giovanni Andrea Angelini Bontempi
# in build_graph_from_dict Nicolaus Adam Strungk has influenced {Richard Wagner}
# added Richard Wagner to Nicolaus Adam Strungk
# in build_graph_from_dict Antonio Lotti has influenced {Richard Wagner}
# added Richard Wagner to Antonio Lotti
# in build_graph_from_dict Johann David Heinichen has influenced {Richard Wagner}
# added Richard Wagner to Johann David Heinichen
# in build_graph_from_dict Johann Adolph Hasse has influenced {Richard Wagner}
# added Richard Wagner to Johann Adolph Hasse
# in build_graph_from_dict Johann Gottlieb Naumann has influenced {Richard Wagner}
# added Richard Wagner to Johann Gottlieb Naumann
# in build_graph_from_dict Ferdinando Paer has influenced {Richard Wagner}
# added Richard Wagner to Ferdinando Paer
# in build_graph_from_dict Francesco Morlacchi has influenced {Richard Wagner}
# added Richard Wagner to Francesco Morlacchi
# in build_graph_from_dict Carl Gottlieb Reißiger has influenced {Richard Wagner, Hermann Berens}
# added Richard Wagner to Carl Gottlieb Reißiger
# added Hermann Berens to Carl Gottlieb Reißiger
# in build_graph_from_dict Julius Rietz has influenced {Richard Wagner, Arthur O'Leary}
# added Richard Wagner to Julius Rietz
# added Arthur O'Leary to Julius Rietz
# in build_graph_from_dict Franz Wüllner has influenced {Richard Wagner}
# added Richard Wagner to Franz Wüllner
# in build_graph_from_dict Ernst von Schuch has influenced {Richard Wagner}
# added Richard Wagner to Ernst von Schuch
# in build_graph_from_dict Fritz Reiner has influenced set()
# in build_graph_from_dict Karl Böhm has influenced set()
# in build_graph_from_dict Giuseppe Sinopoli has influenced set()
# in build_graph_from_dict Bettina von Arnim has influenced {Richard Wagner}
# added Richard Wagner to Bettina von Arnim
# in build_graph_from_dict Johann Wolfgang von Goethe
#  has influenced {Richard Wagner}
# added Richard Wagner to Johann Wolfgang von Goethe
#
# in build_graph_from_dict Amadeus Hoffmann has influenced {Richard Wagner}
# added Richard Wagner to Amadeus Hoffmann
# in build_graph_from_dict Mili Balakirev has influenced {Théodore Akimenko, Richard Wagner}
# added Théodore Akimenko to Mili Balakirev
# added Richard Wagner to Mili Balakirev
# in build_graph_from_dict Mel Bonis has influenced {Richard Wagner, Charlotte Sohy}
# added Richard Wagner to Mel Bonis
# added Charlotte Sohy to Mel Bonis
# in build_graph_from_dict Alexandre Borodine
#  has influenced {Richard Wagner}
# added Richard Wagner to Alexandre Borodine
#
# in build_graph_from_dict Félicien David has influenced {Richard Wagner}
# added Richard Wagner to Félicien David
# in build_graph_from_dict Mikhaïl Glinka has influenced {Richard Wagner}
# added Richard Wagner to Mikhaïl Glinka
# in build_graph_from_dict Friedrich Kalkbrenner has influenced {Ambroise Thomas, Camille-Marie Stamaty, Richard Wagner, José Miró i Anoria}
# added Ambroise Thomas to Friedrich Kalkbrenner
# added Camille-Marie Stamaty to Friedrich Kalkbrenner
# added Richard Wagner to Friedrich Kalkbrenner
# added José Miró i Anoria to Friedrich Kalkbrenner
# in build_graph_from_dict Carl Loewe has influenced {Richard Wagner, Emilie Mayer}
# added Richard Wagner to Carl Loewe
# added Emilie Mayer to Carl Loewe
# in build_graph_from_dict Fanny Mendelssohn has influenced {Richard Wagner}
# added Richard Wagner to Fanny Mendelssohn
# in build_graph_from_dict Modeste Moussorgski has influenced {Richard Wagner}
# added Richard Wagner to Modeste Moussorgski
# in build_graph_from_dict Antoine Reicha
#  has influenced {Eugène Sauzay, Hector Berlioz, Richard Wagner, Alphonse Leduc}
# added Eugène Sauzay to Antoine Reicha
#
# added Hector Berlioz to Antoine Reicha
#
# added Richard Wagner to Antoine Reicha
#
# added Alphonse Leduc to Antoine Reicha
#
# in build_graph_from_dict Clara Schumann has influenced {Richard Wagner}
# added Richard Wagner to Clara Schumann
# in build_graph_from_dict Robert Schumann has influenced {Richard Wagner}
# added Richard Wagner to Robert Schumann
# in build_graph_from_dict Sigismund Thalberg has influenced {Virginia Gabriel, Richard Wagner}
# added Virginia Gabriel to Sigismund Thalberg
# added Richard Wagner to Sigismund Thalberg
# in build_graph_from_dict Giuseppe Verdi
# Jan has influenced {Richard Wagner}
# added Richard Wagner to Giuseppe Verdi
# Jan

# %%
#nx.draw(G1, with_labels=True)#, labels = nx.get_node_attributes(graph, 'nom complet'))
pos = nx.spring_layout(G2, k=1.0, iterations=100)
cpt=0
labels={}
to_be_removed=set()
for n in G2.nodes():
    if "Richard" in n.name:
        if cpt==0:
            labels[n]=str(n)
            cpt+=1
            main_node=n
        else :
            for neighbor in G2.successors(n):
                G2.add_edge(main_node, neighbor, **G2[duplicate_node][neighbor])
            to_be_removed.add(n)
    elif not str(n).startswith("Q"): 
        labels[n]=str(n)
    else:
        labels[n]=""

for n in to_be_removed:
    G2.remove_node(n)

# Draw the graph
plt.figure(figsize=(12, 11.5))
nx.draw_networkx(
    G2,
    pos=pos,
    labels=labels,
    with_labels=True,
    node_color='skyblue',
    edge_color='gray',
    node_size=800,
    font_size=7,
    font_weight='bold',
    arrows=True
)
plt.title("Graphe d'influences construit sur Wagner", fontsize=16)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
""" problème car sigma n'accepte pas Composer comme type pour les noeuds du graphe
graph = G
#for source, target, in graph.edges:
#    graph.edges[source, target]["color_edge"] = graph.nodes[target]["color"]
layout = {}
grid_positions = {}

angle_step = 2 * math.pi / max(1,len(graph.nodes()))
radius = 1
for i,node in enumerate(graph.nodes()):
    angle = i * angle_step
    layout[node] = {
        "x": radius * math.cos(angle),
        "y": radius * math.sin(angle)
    }

# Calcul d'un score de PageRank pour ajuster la taille des noeuds par exemple
pagerank_scores = nx.pagerank(graph)

# Visualisation avec ipysigma
sigma = Sigma(
    graph=graph,
    #raw_node_color="color",
    #raw_edge_color="color_edge",
    layout=layout,
    node_label="nom complet",
    default_edge_type="curve",
    node_border_color_from="node",
    label_font="cursive",
    node_size=pagerank_scores,  # On peut également multiplier par un facteur si nécessaire
)


# Pour afficher dans Jupyter Notebook (si ipysigma est intégré dans un widget)
sigma"""


def prepare_sigma_with_composer_ids(original_graph):
    """Relabels a graph using Composer.id as node labels and returns a Sigma widget."""
    #id_map = {node: int(node.id.replace('Q','')) for node in original_graph.nodes()}
    id_map={node: str(node)+" - "+str(node.id) for node in original_graph.nodes()}
    graph = nx.relabel_nodes(original_graph, id_map)

    # Clean all node/edge attributes to make sure they're JSON serializable
    for n, d in graph.nodes(data=True):
        for k, v in d.items():
            if not isinstance(v, (str, int, float, bool, type(None))):
                d[k] = str(v)

    for u, v, d in graph.edges(data=True):
        for k, val in d.items():
            if not isinstance(val, (str, int, float, bool, type(None))):
                d[k] = str(val)

    layout = {
        node: {
            "x": math.cos(i * 2 * math.pi / len(graph)),
            "y": math.sin(i * 2 * math.pi / len(graph)),
        }
        for i, node in enumerate(graph)
    }

    pagerank_scores = nx.pagerank(graph)

    for k, v in pagerank_scores.items():
        assert isinstance(v, (int, float)), f"Non-numeric pagerank for node {k}: {v}"

    sigma = Sigma(
        graph=graph,
        layout=layout,
        default_edge_type="curve",
        node_border_color_from="node",
        label_font="cursive",
        node_size=pagerank_scores
    )

    return sigma

#prepare_sigma_with_composer_ids(G)
import pickle
from ipysigma import Sigma

def sigma_graph_from_file(filename):
    G = pickle.load(open(filename, 'rb'))
    return G,prepare_sigma_with_composer_ids(G)
    

#S=prepare_sigma_with_composer_ids(G)
#G,S = sigma_graph_from_file("dict_keys(['Q134085', 'Q3398651', 'Q450483', 'Q347190', 'Q594586', 'Q1192', 'Q312979', 'Q7945638', 'Q2837653', 'Q49325']).pickle")
#G,S = sigma_graph_from_file("Q1387086.pickle")
#G,S = sigma_graph_from_file("Q964256.pickle")
G,S = sigma_graph_from_file("Q50187.pickle")
#nx.draw(G,with_labels=True)
S

# %%
G,S = sigma_graph_from_file("Q313374.pickle")
#nx.draw(G,with_labels=True)
S

# %%
G,S = sigma_graph_from_file("Q205519.pickle")
#nx.draw(G,with_labels=True)
S

# %%
print(len(["César Franck","Gabriel Pierné","Henri Duparc","Jean Cras","Charles-Marie Widor","Louis Vierne","Alexandre Guilmant","Marcel Dupré","Eugène Gigout","Jehan Alain","Charles Tournemire","Gabriel Dupont","Déodat de Séverac","Vincent d'Indy","Albert Roussel","Olivier Messiaen","Pierre Boulez", "Naji Hakim","Edgar Varèse", "Tristan Murail","Gérard Grisey","Claude Debussy","Maurice Ravel","Gabriel Fauré","Reynaldo Hahn","Gustave Samazeuilh","Paul Ladmirault","Paul Le Flem","Philippe Hersant","Maurice Duruflé","Thierry Escaich","Yves Castagnet","Eric Lebrun","Jean-Philippe Rameau","Louis Couperin","Claude Balbastre","Arthur Honegger","George Auric","Francis Poulenc","Germaine Taillefer","Darius Milhaud","Louis Durey","Guy Ropartz","Henri Rabaud","Sylvio Lazzari","Louis Aubert","Charles Munch","Hector Berlioz","André Caplet","André Jolivet","André Messager","Yves Baudrier","Erik Satie","Jules Massenet","Charles Gounod","Georges Bizet","Ernest Chausson","Jacques Offenbach","Étienne Nicolas Méhul","André Grétry","François-Joseph Gossec","Jean-François Lesueur","Adolphe Adam","François-Adrien Boieldieu","Léon Boëllmann","Camille Saint-Saëns","Florent Schmitt","Charles-Valentin Alkan","Ambroise Thomas","Alexandre-Pierre-François Boëly","Léo Delibes","Michel-Richard de Lalande","Marin Marais","Marc-Antoine Charpentier","Louis-Nicolas Clérambault","André Campra","Henry Desmarest","Nicolas de Grigny","Joseph Bologne de Saint-George","Jacques Ibert"]))
