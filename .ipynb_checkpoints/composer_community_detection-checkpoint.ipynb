# %%
import networkx as nx
import numpy as np
import math
import time
import pickle
from ipysigma import Sigma
from composer import * 
#from influence_graph import *

# %%
from bs4 import BeautifulSoup
import requests
import re
import networkx as nx
import spacy
import time
import pickle
import json
from composer import *


"""les relations d'influence entre compositeurs sont qualifiées plus précisément qu'avec la seule présence de l'un dans la page wikipedia de l'autre grâce à la fonction orienting with dates"""
"""compléter avec les influences - même peu nombreuses - spécifiées dans wikidata, en plus de celles des élèves - réfléchir jusqu'où aller dans la profondeur des élèves """
"""ajouter une détection des liens vers des pages de compositeurs sur wikipedia"""

def get_person_entities(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    L=[]
    for ent in doc.ents:
        if ent.label_=='PERSON':
            #print(ent.text, ent.start_char, ent.end_char, ent.label_)
            L.append(ent.text)
    #print(L)
    return L

def get_wikipedia_page_text(name,language="en"):
    url = f"https://{language}.wikipedia.org/w/index.php?search={name}"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    text=soup.get_text()
    if language =="en" and (name+" - Wikipedia" in text or name.split(" ")[-1]+" - Wikipedia" in text):
        return get_wikipedia_page_text(name+" (composer)")
    elif language=="fr" and (name+" - Wikipédia" in text or name.split(" ")[-1]+" - Wikipédia" in text):
        return get_wikipedia_page_text(name+" (compositeur)")
    return text

def composer_filter_by_dict(list_of_names, dico):
    """filtre les noms qui sont ceux de compositeurs à partir d'un dictionnaire de compositeurs, évite d'avoir à rechercher dans wikidata à chaque fois donc plus rapide mais moins robuste, à compléter peut-être avec le TD qui utilisait des Trie"""
    list_of_names = list(filter(lambda x: x.strip() in dico, list_of_names))
    return list_of_names

#composer_filter_by_dict(["Richard Wagner","Bach","Mozart"],{"Richard Wagner":(1813,1883),"Johann Sebastian Bach":(1685,1750)})

def composer_filter(list_of_names):
    compo_dico={}
    cpt=0
    for n in list_of_names:
        c_id = find_id(n)
        if c_id is not None and c_id not in compo_dico:
            c = is_composer(c_id,n)
            #print(is_composer(n))
            if c is not None :
                if cpt==0:
                    compo=c
                compo_dico[c_id]=c
                print(n,c_id,f"is the composer number {cpt} found in {compo}'s page")
                cpt+=1
    return compo,compo_dico


def find_compositional_influences(name,fr=False):#problème : l'algo saute souvent Beethoven, y compris chez Wagner
    content = get_wikipedia_page_text(name)
    if fr:
        content+=get_wikipedia_page_text(name,"fr")
    persons = get_person_entities(content)
    return(composer_filter(persons))

def build_list_of_influences(enum_of_composers,french=False):
    list_of_influ_dict=[]
    for composer in enum_of_composers:
        list_of_influ_dict.append(find_compositional_influences(composer,fr=french))
    return list_of_influ_dict



def orienting_with_dates(list_of_dico,compo_dico={}):
    """completing the influences of all encountered compsoers; orienting the influence relations when no doubt exists because of birth-death dates"""

    for compo,dico in list_of_dico:
        cpt=0
        b=False #boolean equal to True iff we have access the the birth date of the first composer
        d=False #boolean equal to True iff we have access the the death date of the first composer
        #print(dico)
        for c in dico.values():

            if c.id not in compo_dico :
                compo_dico[c.id]=c

            if cpt==0: #the first element of each dictionary is the one whose wikipedia page was used to retrieve all the others present in the current dictionary
                #compo = compo_dico[c.id]
                cpt+=1
                print("1st composer of this page :",compo,compo.id,compo_dico[compo.id].influences)
                birth_date_compo = compo.birth
                death_date_compo = compo.death
                if birth_date_compo is not None :
                    print("db:"+str(compo.birth))
                    b = True

                if death_date_compo is not None :
                    print("dd:"+str(compo.death))
                    d = True

            else :
                birth_date = c.birth
                death_date = c.death

                if d and birth_date is not None:
                    if birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        compo_dico[compo.id].influences.add(c)
                        #print(f"added {c} to {compo_dico[compo.id]}")
                    elif b and death_date is not None:
                        if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")
                        else:
                            compo_dico[compo.id].influences.add(c)
                            #print(f"added {c} to {compo_dico[compo.id]} in the new way")
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")
                    else:
                        compo_dico[compo.id].influences.add(c)
                        #print(f"added {c} to {compo_dico[compo.id]}")
                        compo_dico[c.id].influences.add(compo)
                        #print(f"added {compo_dico[compo.id]} to {c}")

                elif b and death_date is not None:
                        if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")
                        #elif d and birth_date is not None:
                        #    if birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        #        compo_dico[compo.id].influences.add(c)
                        else:
                            compo_dico[compo.id].influences.add(c)
                            #print(f"added {c} to {compo_dico[compo.id]}")
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")

                else:#we cannot say anything for sure since they were contemporary so by default we assume they influenced each other
                    compo_dico[compo.id].influences.add(c)
                    #print(f"added {c} to {compo_dico[compo.id]}")
                    compo_dico[c.id].influences.add(compo)
                    #print(f"added {compo_dico[compo.id]} to {c}")
        print(compo_dico[compo.id],"has influenced",compo_dico[compo.id].influences)

    return compo_dico



def build_graph_from_dict(compo_dico,G=nx.DiGraph()):
    for compo in compo_dico.values():
        print("in build_graph_from_dict",compo,"has influenced",compo.influences)
        for c in compo.influences:
            G.add_edge(compo,c)
            print(f"added {c} to {compo_dico[compo.id]}")

    # save graph object to file
    pickle.dump(G, open(str(next(iter(compo_dico.keys())))+".pickle", 'wb'))
    return G

def graph_of_influences(list_of_compo_names,fr=True,G=nx.DiGraph()):
    list_of_influ_dicts=build_list_of_influences(list_of_compo_names,fr)#put false if you're only interested in the english wiki
    compo_dico = orienting_with_dates(list_of_influ_dicts)
    return build_graph_from_dict(compo_dico,G)

# %%
def prepare_sigma_with_composer_ids(original_graph):
    """Relabels a graph using Composer.id as node labels and returns a Sigma widget."""
    #id_map = {node: int(node.id.replace('Q','')) for node in original_graph.nodes()}
    id_map={node: str(node)+" - "+str(node.id) for node in original_graph.nodes()}
    graph = nx.relabel_nodes(original_graph, id_map)

    # Clean all node/edge attributes to make sure they're JSON serializable
    for n, d in graph.nodes(data=True):
        for k, v in d.items():
            if not isinstance(v, (str, int, float, bool, type(None))):
                d[k] = str(v)

    for u, v, d in graph.edges(data=True):
        for k, val in d.items():
            if not isinstance(val, (str, int, float, bool, type(None))):
                d[k] = str(val)

    layout = {
        node: {
            "x": math.cos(i * 2 * math.pi / len(graph)),
            "y": math.sin(i * 2 * math.pi / len(graph)),
        }
        for i, node in enumerate(graph)
    }

    pagerank_scores = nx.pagerank(graph)

    for k, v in pagerank_scores.items():
        assert isinstance(v, (int, float)), f"Non-numeric pagerank for node {k}: {v}"

    sigma = Sigma(
        graph=graph,
        layout=layout,
        default_edge_type="curve",
        node_border_color_from="node",
        label_font="cursive",
        node_size=pagerank_scores
    )

    return sigma

#prepare_sigma_with_composer_ids(G)
import pickle
from ipysigma import Sigma

def sigma_graph_from_file(filename):
    G = pickle.load(open(filename, 'rb'))
    return G,prepare_sigma_with_composer_ids(G)
    


#G,S = sigma_graph_from_file("Q205519.pickle")
#S
#G=graph_of_influences(["Paul Le Flem","Jean Cras"])
#G=pickle.load(open("Q964256.pickle", 'rb'))
G=pickle.load(open("Q1339.pickle", 'rb'))
S = prepare_sigma_with_composer_ids(G)
S
# Out:
# Sigma(nx.DiGraph with 718 nodes and 1,285 edges)

# %%
"""Louvain"""
"""
Louv=nx.community.louvain.louvain_communities(G,weight='weight')
print("number of communities with Louvain algorithm : ",len(Louv))
print(Louv,"\n")
"""
#K=G.to_undirected(reciprocal=False, as_view=False)
"""k-cliques"""
"""
L=[list(nx.community.k_clique_communities(K,i)) for i in range(2,12)]
lens=list(map(len,L))
print(lens)#number of communities found for each k value between 2 and 11
L=list(nx.community.k_clique_communities(K,5))#for k=5 the maximum number of communities (4) is obtained
print("number of communities with k-cliques algorithm for k = 5 : ", len(L))
print(L,"\n")
"""

"""Girvan-Newman"""
import itertools
"""N=79
comp = nx.community.girvan_newman(K)
for communities in itertools.islice(comp, N):
    print(len(tuple(sorted(c) for c in communities)))"""
k = 4 #number of communities we want to separate
comp = nx.community.girvan_newman(G)
limited = itertools.takewhile(lambda c: len(c) <= k, comp)
i=1
for communities in limited:
    print("number of communities with Girvan-Newman algorithm after", str(i), " iterations : ", len(communities))#tuple(sorted(c) for c in communities)
    i+=1
#print(tuple(sorted(c) for c in communities),"\n")
print(communities)


"""label propagation"""
"""
labcommus=nx.community.label_propagation_communities(G)
print("number of communities with label propagation : ", len(labcommus))
print(labcommus)
"""
# Out:
# number of communities with Girvan-Newman algorithm after 1  iterations :  2
# number of communities with Girvan-Newman algorithm after 2  iterations :  3
# number of communities with Girvan-Newman algorithm after 3  iterations :  4
# ({Albert Schweitzer, Jacobus Gallus, Q704174, Reynaldo Hahn, Glenn Gould, Johann Sebastian Bach, Albinoni, Luc-André Marcel, John Coltrane, Poulenc, William A., Q1710371, Johann Ernst Bach, Henry Lawes, Johann Gottfried Schicht, Attilio Ariosti, Bernardo Pasquini, Q215995, John Eliot Gardiner, Massenet, John Christopher Smith, Johann Friedrich Doles, Alessandro Scarlatti, Beck, Vivaldi, Joe Hisaishi, Johann Gottfried Bernhard, Q453100, Q311625, Q960222, Samuel Arnold, Antonio Bernacchi, Heinrich Schütz, Johann David Heinichen, Antonio Calegari, Bodin de Boismortier, Q730234, Q4775711, Q1445590, Wilhelm Friedemann, Q4888380, Q23021179, Gustav Schreck, Anthony Hedges, Philippe Gaubert, Q314221, Q875506, Q508635, Michel Corrette, Q55758134, Christoph Graupner, Q1347677, Johannes Galliculus, Johann Kuhnau, G.F. Handel, Dietrich Buxtehude, musicien de ville, Richard Wagner, John Stanley, Q442963, Q57369, Q436126, Samuel Scheidt, Wolfgang Jünger, Antonio Giay, ↑ Paul Badura-Skoda, John Taylor, Mauro Giuliani, Gottlieb Muffat, Q1339, Q506627, Q350221, Raphaël Imbert, Wolfgang Figulus, Jean-Joseph Mouret, Q1337261, Q57250484, William Boyce, Brahms, C. P. E. Bach, Charles-Marie Widor, Gounod, compositeur de la Chapelle, Johann Hermann Schein, William Brade, Q4160549, John Taylor, Jacquet de La Guerre
# , John Frederick Lampe, Johann Adam Reinken, Q679477, Johann Christian Bach, Debussy, Q554209, François Couperin, Charles Jennens, Telemann, McCartney, Q57225, Messiaen, Winton Dean, Scott Speck, Tobias Michael, Johann Krieger, Q1405923, Alexandre Astier, Lorenz Christoph Mizler, Johann Kuhnau, Corelli, Q372593, Joseph Bodin de Boismortier, Reinhard Keiser, Wilhelm Rust, Karl Richter, Johann Adolph Hasse, ↑ Hogwood, Q1525931, Johann Caspar Kerll, Q69400, Thierry Escaich, élève de Johann Pachelbel, J. Pachelbel, Filippo Amadei, Giovanni Bononcini, Johann Adam Hiller, jean-christian-michel.com, Q311625, Q873647, Sebastian Knüpfer, Günther Ramin, Gott, Wilhelm Furtwängler, Charles Gounod, Q213556, Johann Mattheson, Q395725, Hermann Scherchen, Q446955, Nicola Porpora, Q57829, Gustav Leonhardt, Johann Schelle, Q216090, Q959391, Agostino Steffani, Q323113, Anne Amélie de Prusse, Q960222, William Crotch, Q551943, Q445121, Q7349, Q436126, Q64880, Q503355, Wilhelm Friedemann, Q124772, Antonio Vivaldi, Wendy Carlos, Q435198, Carl Heinrich Graun, Friedrich Wilhelm Zachow, Q91966, Handel, Q549550, Magdalena Bach, Girolamo Frescobaldi, Q7302, Johann Nikolaus Forkel, Q377768, Robert Schumann, John Mainwaring, Q60724, Gottfried van Swieten, maître de chapelle Bach, Nikolaus Harnoncourt, Antonio Lotti, Johann Sebastian Bach, Johann Christoph Friedrich Bach, Q545409, Christoph Biller, Charles Burney, Vincent Lübeck, Q523528, Q157777, H.C. Robbins, Q445696, Éric Lebrun, Padre Martini, Francesco Antonio Urio, Q1526310, Christoph Wolff, Antonio Caldara, Jean-Adolphe Ier de Saxe-Weissenfels, Carl Philipp Emanuel Bach, Karl Straube, Francesco Gasparini, Q3745255, Domenico Scarlatti, Jean-Philippe Rameau, Q691733, Johann Gottlob Harrer, Q77212, Q104107, Q3836967, Johann Bach, Christoph Graupner, Leonardo Vinci, Giacomo Carissimi, Carl Friedrich Zelter, Quincy Jones, Q771789, Corelli, Q3904094, Q55524, Couperin, Wilhelm Friedrich Ernst Bach, Ernst Ludwig de Hesse-Darmstadt, Q46096, Percy Grainger, Johann Ambrosius, Mozart, Q3619312, Q545409, Johann Heinrich Rolle, Bach, Q1339, Marc Matthys, Otto Erich Deutsch, Q1525889, Q183087, Q68255, Ludwig van Beethoven, Adrien Rougier, Q5563833, Q543891, Keith Jarrett, Johann Christoph Bach, Q3638796, Q60965, Jordi Savall, Wolfgang Schmieder, Q3904181, Q67366}, {Josef Suk, Franz Clement, Christophe Looten, Edward MacDowell, Carl Schuricht, Carl Loewe, Q447851, Liszt, Q706139, Grigory Ginzburg, Q93373, Q778890, Josef Bohuslav Foerster, Hans von Bulow, Eduard Hanslick, Q66818, Q724497, Q721465, Mel Bonis, Q270464, Leonidas Kavakos, Q5126007, Paul Hindemith, Ján Cikker, Woody Allen, Horatio Parker, Q322323, Josef Suk, Q152043, Philippe Autexier, Joaquín Turina, Louise Japha, Ignaz Schuppanzigh, György Kurtág, Q200867, Janet Baker, Anton Diabelli, Alexander Moyzes
# , Alexander Borodin, Arnold Schoenberg, Friedrich Kalkbrenner, Q713949, Q20004429, Ian McDonald, Dmitri Shostakovich, Mogens Wöldike, Q1029284, Károly Goldmark, Oskar Nedbal, Claude Vivier, Q45682, Heinz Holliger, Q119432, Bruckner, Nikolai Rimsky-Korsakov, Zoltán Kodály, Otilie Suková, Yo-Yo Ma, Benjamin Britten, Eduard Hanslick, Magnus Lindberg, Chopin, Q701340, Donald Tovey, Nepomuk Maýr, Leoš Janáček, de composer deux, Q45825712, Q56310080, Q2142506, Witold Lutosławski, Aulis Sallinen, Victor Herbert, Aaron Copland, Hans von Bülow, Antonín Bennewitz, Q519693, Sigismund Thalberg, Johann Friedrich Schubert, Rudolf Tobias, Karel Knittl, Arvo Pärt, Giuseppe Tartini, Claudio Abbado, Q312700, Boleslav Yavorsky, Q232255, Webern, Bettina von Arnim, Ludwig van Beethoven Ludwig van Beethoven, John Eliot Gardiner, Niels Gade, Q1351430, Q297717, Rafael Kubelík, Q80135, Robert Schumann, Q1246313, Alfred Brendel, Mstislav Rostropovich, Wilhelm Furtwängler, Johann Herbeck, François-Joseph Fétis, Q69376, Leonid Nikolayev, Bettina von Arnim, Antoine Reicha
# , Q709658, Q48363, Q1151, de Rossini, Jonathan Berger, de la guerre, Mořic Anger, Lev Oborin, Johann Wolfgang von Goethe
# , Q50333026, Bedřich Smetana, William Walton, Anton Bruckner, Q50187, Floex, Mili Balakirev, Karel Bendl, Tikhon Khrennikov, Q41309, Andrés Segovia, Krystian Zimerman, Q255300, Q2000816, Nikolaus Zmeskall, Q437262, Q2194365, Karl Böhm, Q157785, Bruckner, Hector Berlioz, Josef Zvonař, Q374582, Joseph Joachim, František Ondříček, Jeannette Thurber, Q2430552, Q347611, Q771789, Q97274399, Q5592848, Gavriil Popov, Q213558, Q2394722, Q78524, Q286062, Felix Mendelssohn, Karel Ancerl, Q434601, Q368583, George Enescu
# , Luigi Boccherini, Yasuaki Shimizu, Alexander Dargomyzhsky, Q5460707, Leonard Bernstein, Felix Draeseke, Giuseppe Verdi
# Jan, Vincent d'Indy, Olivier Messiaen, Q5416317, Q110224410, Amadeus Hoffmann, Murray Schafer, Q8112426, Sigismund Thalberg, Modeste Moussorgski, Mahler, Joaquín Rodrigo
# , Jarmil Burghauser, Q7934272, Barry Cooper, Fritz Stiedry, Q5434007, Richard Wagner, Arthur Honegger, Giacomo Meyerbeer, Paul Badura-Skoda, Ralph Vaughan Williams, Duke Ellington, Johann Georg Albrechtsberger, Q5298438, Witold Lutosławski, Q153776, Dmitry Kabalevsky, Robert Schumann, Q151953, Q200867, Czech Composer, Q255, Q457711, Q1988504, Louis van Beethoven, Q215333, Q347611, Q311387, Q531569, Q16013625, Antonio Zingarelli, Kaspar Anton Karl van Beethoven, Johann Philipp Kirnberger, Brahms, Q6013167, Q7298, Q3180496, bon musicien, Keith Jarrett, Q544277, Daniel Gottlob Türk, Miaskovski, Q706221, Joséphine von Brunsvik, Enrique Granados
# , Charles Villiers Stanford, Gerard McBurney, Leopold Stokowski, Harrison Birtwistle, Fanny Mendelssohn, Q726973, Nikolaus Harnoncourt, Günter Raphael, Ignaz Seyfried, Q534512, Evelyn Glennie, David Haas, Q310431, Ferdinand David, Q565070, Sergei Prokofiev, Rodolphe Kreutzer, Nannette Streicher, Robin Holloway, Carl Czerny, Mikhaïl Glinka, Paganini, Q311389, Joonas Kokkonen, Kaija Saariaho, Q41309, Liszt, Q1029423, Aram Khachaturian, Q159569, Johann Michael Vogl, Q191917, Bruno Walter, Q57178, Mikhaïl Glinka, Vissarion Shebalin, Q881741, Q155540, András Schiff, Clara Schumann, Q721465, Benjamin Britten, Q6004693, Félicien David, Andreas Streicher, Heinrich Isaac, Lev Lebedinsky, Carl Maria von Weber, Robert Levin, Q58008, György Ligeti, Q4974772, Q2062832, Felix Mendelssohn, Pyotr Ilyich Tchaikovsky, Carl Maria von Bocklet, Ferdinand von Waldstein, Silvestre Revueltas, Louis Spohr, Paul Badura-Skoda, Fiodor Droujinine, Giovanni Paisiello, Modeste Moussorgski, Q60908, Erik Bergman, Richard Wagner, Esa-Pekka, Bettina von Arnim, Q215083, Gustav Mahler, musicien de tous, Woody Allen, Anton Schindler, Bernard Zweers
# , Miles Davis, Dvorak, Janet Baker, Q819749, Q11457729, Usko Meriläinen, Szpinalski, Leonard Bernstein, Sofia Gubaidulina, Ignaz Moscheles, Alexander Glazunov, Ignacy Paderewski, Q46096, Q724254, Arturo Toscanini, Q202672, Johann Franz Xaver Sterkel, Antonín Liehmann, Xavier Darasse, Q55214796, Q322210, Carl Nielsen, Mel Bonis, Q710458, Krzysztof Meyer, Q2399157, Elmira Nazirova, Johann van Beethoven, Alexandre Borodine
# , Giacomo Meyerbeer, Antonio Salieri, Anton Bruckner, Kirill Zaborov, Brahms, Wolfgang Amadeus Mozart, Wilhelm Furtwängler, Pierre Boulez, Bruno Walter
# Pianistes, Q17634412, Karl Böhm, Arnold Alschwang, Q1939469, Otto Jahn, Ignacy Paderewski, Thomas Adès, Ignaz Schuppanzigh, Schubert, Giuseppe Verdi
# Jan, Carlos Chávez, Joan Baez, Joseph Joachim, François Schubert, Richard Wagner, Robert Schumann, Robert Schumann, Carl Loewe, Leonard Bernstein, Q953007, Saverio Mercadante, Q366536, Q467738, Friedrich Kalkbrenner, Gioachino Rossini, Q16334134, Jordi Savall, Arrigo Boito, Mili Balakirev, Tristan Murail, Ludwig Schnorr von Carolsfeld, Henry Cowell, Mili Balakirev, Franz Liszt, Gesang, Franz von Schober, Joseph von Spaun, Mylène Farmer, Eduard Marxsen, Jean Sibelius, Pierre Bartholomée, Alfred Einstein, Rafael Kubelík, Q90721, Q1159997, Hans Abrahamsen, Ernst Hilmar, Wilhelm Müller, Q315150, Mel Bonis, Tarja Turunen, Q7294, Nicolas Nabokov, Félicien David, Sergiu Celibidache, Brahms, Antoine Reicha
# , Jan Swafford, Johann Mayrhofer, Josef Hellmesberger, Q77177, Otto Erich Deutsch, Brahms, Q57210, Antonio Salieri, Giuseppe Verdi
# Jan, Claudio Abbado, Carl Loewe, Anselm Hüttenbrenner, Johann Strauss, Wilhelm Backhaus, Karel Komzák's, Kaija Saariaho, Peter Schreier, Schubert, Clara Schumann, de Nikolaus Harnoncourt, Q113484550, Johann Strauss, Alexandre Borodine
# , Maximilian Steinberg, Josef Foerster, Q35624448, Richard Wagner, Giacomo Meyerbeer, Amadeus Hoffmann, Ferdinand Schubert, Alexandre Borodine
# , Anton Schindler, Franz Anton Schubert, Clara Schumann, Sigismund Thalberg, Stravinsky, Mendelssohn, Hans von Bülow, Q323435, Leevi Madetoja, Q7298, Johann Philipp Neumann, Harry Burleigh, Antonín Dvořák, Giacomo Meyerbeer, Brian Newbould, Johann Wolfgang von Goethe
# , Q565548, Karel Ančerl, Franz Liszt, Fanny Mendelssohn, Brahms, Mikhaïl Glinka, Q1280917, András Schiff, Modeste Moussorgski, ami de Schubert, Q312700, Louis Ehlert}, {Maria Wilhelmine Thun, Q113911, Gluck, Franz von Walsegg, Giuseppe Verdi, Wolfgang Hildesheimer, Q697804, Charles Rosen, Robert Levin, Claudio Abbado, Jean-Chrétien Bach, Emanuel Schikaneder, Pierre Barbaud, Antonio Polzelli, Christian Cannabich, Grétry, Karl Friedrich Abel, Q79104, Freystadler, Q14421, Joseph Weigl, Marianne von Genzinger, Q5045261, Maria Anna Mozart, Jason Schwartzman, Q157898, Ignaz Pleyel, Howard Chandler Robbins Landon, ↑ Tia DeNora, Gottfried van Swieten, Leopold Mozart, Thomas Linley, Q151953, Luigi Tomasini, Mozart de Bologne, Joseph Haydn, Roman Hoffstetter, de chapelle Werner, Karl Thomas Mozart, Johann Strauss II, Q310518, jeune compositeur, Charles Burney, Pietro Antonio Lorenzoni, Michael Haydn, George Bridgetower, autrichien de la période, ↑ Philippe Autexier, Gioachino Rossini, librettiste Lorenzo da Ponte, Mozart, Q154812, Peter Hänsel, Luigi Cherubini, Johann Joseph Fux, Otto Erich Deutsch, Wolfgang Mozart, Johannes Brahms, Q698066, Giacomo Meyerbeer, Mendelssohn, Wolfgang Amadeus Mozart, Q1712216, Giovanni Paisiello, Jacques Chailley, Nicola Porpora, Joseph Lange, Robert Kimmerling, Joseph Legros, Q689576, Antonín Kraft, Carl Maria von Weber, Beethoven, Abund Mikysch, Joseph Haydn, Paul Wranitzky, Paul Badura-Skoda, Nicolas Slonimsky, Q672225, Léopold Mozart, Schubert, Benjamin Britten, Louis Spohr, Johann Spech, András Schiff, Albert Christoph Dies, Carl Friberth, David Wyn Jones, Johann Schobert, Johann Peter Salomon, Gluck, Patrick Taïeb, ↑ Henri Kling, George Sand, Eva Badura-Skoda, Q254, Robert Schumann, Anton Walter, Johann Tost, Joseph Haydn, Arthur Hutchings, Witold Lutosławski, Franciszek Lessel, maître de chœur, Nicolas Ier Joseph Esterházy, György Ligeti, de Salieri, Nicolas II Esterházy, Q20665628, Mozart, Antonio Salieri, Q272236, Alfred Einstein, Johann Nepomuk Hummel, Q43704749, Kaija Saariaho, Luigi Cherubini, Q316903, d'orchestre qu'il, Q3816382, Arthur Honegger, Brahms, Gluck, Q1348126, Ludwig von Köchel, Clementi, Saverio Mercadante, Johann Michael Puchberg, Mathias Haydn Mathias Haydn, Q215333, Q882123, Q313917, Muzio Clementi, Franz Xavier Süssmayer, Marianne de Martines, de Paul II Anton Esterházy, Arrigo Boito, Q362139, Q768095, Q25999335, Cimarosa, Anton Wranitzky, Joseph Legros, Luigia Polzelli, Robbins Landon, Q157777, Michael Haydn, Robert Levin, Friedrich Kalkbrenner, Leopold Mozart, Ignacy Paderewski, Christopher Hogwood, Woody Allen, ↑ Wolfgang}, {Friedrich Kalkbrenner, Alexandre Borodine
# , Richard Wagner, Delphine von Schauroth, Liszt, Edward Dannreuther, Joseph Joachim Raff, Bettina von Arnim, Mel Bonis, Wilhelm Furtwängler, Q214805, Carl Friedrich Zelter, Carl Loewe, Rena Kyriakou, Q69376, Félicien David, Modeste Moussorgski, Giacomo Meyerbeer, Tchaikovsky, Hector Berlioz, Claudio Abbado, Mili Balakirev, Sigismund Thalberg, Antoine Reicha
# , Jean-Baptiste Robin, Felix Mendelssohn, Mikhaïl Glinka, Michel Corboz, Woody Allen, Anton Bruckner, Robert Schumann, Otto Klemperer, Fanny Mendelssohn, Johann Wolfgang von Goethe
# , Johann Christian Lobe, Giuseppe Verdi
# Jan, Clara Schumann, Niels Wilhelm Gade, Philippe Herreweghe})
# '\nlabcommus=nx.community.label_propagation_communities(G)\nprint("number of communities with label propagation : ", len(labcommus))\nprint(labcommus)\n'

# %%
from composer import * 
#g=pickle.load(open("Q964256.pickle", 'rb'))
#g=pickle.load(open("Q1339.pickle",'rb'))
g=pickle.load(open("Q205519.pickle",'rb'))
id_map={node: str(node)+" - "+str(node.id) for node in g.nodes()}
graph = nx.relabel_nodes(g, id_map)

# Clean all node/edge attributes to make sure they're JSON serializable
for n, d in graph.nodes(data=True):
    for k, v in d.items():
        if not isinstance(v, (str, int, float, bool, type(None))):
            d[k] = str(v)

for u, v, d in graph.edges(data=True):
    for k, val in d.items():
        if not isinstance(val, (str, int, float, bool, type(None))):
            d[k] = str(val)

"""layout = {
    node: {
        "x": math.cos(i * 2 * math.pi / len(graph)),
        "y": math.sin(i * 2 * math.pi / len(graph)),
    }
    for i, node in enumerate(graph)
}"""

pagerank_scores = nx.pagerank(graph)

for k, v in pagerank_scores.items():
    assert isinstance(v, (int, float)), f"Non-numeric pagerank for node {k}: {v}"

era_categories = ["Medieval","Baroque", "Classique", "Romantique", "XXe", "contemporain"]
colors = {
    "Medieval": "#654321", #Brown
    "Baroque": "#2ECC71",      # Green
    "Classique": "#F1C40F",    # Yellow
    "Romantique": "#E74C3C",       # Red
    "XXe": "#3498DB",  # Blue
    "contemporain": "#7F00FF", #Lilac
    "Unknown": "#95A5A6"
    
}

partitions = {"Medieval":[],"Baroque":[], "Classique":[], "Romantique":[], "XXe":[], "contemporain":[],"Unknown":[]}

for node in g.nodes:
    era = node.get_era()  # Default to "medium"
    graph.nodes[str(node)+" - "+str(node.id)]["color_node"] = colors.get(era, "#95A5A6")  # Gray if unknown
    #g.nodes[node]["size"] = 10  # Set a default size
    #partitions[era].append(graph.nodes[str(node)+" - "+str(node.id)])
    partitions[era].append(str(node)+" - "+str(node.id))


for source, target in graph.edges:
    graph.edges[source, target]["color_edge"] = graph.nodes[target]["color_node"]

layout = {}

# Grid positions for each era cluster center
grid_positions = {
    "Medieval": (0, 0),
    "Baroque": (-3, 0),
    "Classique": (0, 2),
    "Romantique": (3, 0),
    "XXe": (-2, -2),
    "contemporain": (2, -2)
}

# Assign circular layouts within each cluster
for era, node_names in partitions.items():
    base_x, base_y = grid_positions.get(era, (0, 0))
    angle_step = 2 * np.pi / max(1, len(node_names))
    radius = 1.5  # Distance from center of cluster

    for i, node_name in enumerate(node_names):
        angle = i * angle_step
        layout[node_name] = {
            "x": base_x + radius * np.cos(angle),
            "y": base_y + radius * np.sin(angle)
        }

# Visualize with ipysigma
sigma = Sigma(
    graph,
    raw_node_color="color_node",
    raw_edge_color="color_edge",
    layout=layout,
    node_label="label",
    default_edge_type="curve",
    node_border_color_from="node",
    label_font="cursive",
    node_size=graph.out_degree()
    #nx.pagerank(graph)
)

sigma
# Out:
# Sigma(nx.DiGraph with 2,648 nodes and 8,829 edges)
