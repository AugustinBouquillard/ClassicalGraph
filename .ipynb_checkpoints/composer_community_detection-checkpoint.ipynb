# %%
import networkx as nx
import numpy as np
import math
import time
import pickle
from ipysigma import Sigma
from composer import * 
#from influence_graph import *

# %%
from bs4 import BeautifulSoup
import requests
import re
import networkx as nx
import spacy
import time
import pickle
import json
from composer import *


"""les relations d'influence entre compositeurs sont qualifiées plus précisément qu'avec la seule présence de l'un dans la page wikipedia de l'autre grâce à la fonction orienting with dates"""
"""compléter avec les influences - même peu nombreuses - spécifiées dans wikidata, en plus de celles des élèves - réfléchir jusqu'où aller dans la profondeur des élèves """
"""ajouter une détection des liens vers des pages de compositeurs sur wikipedia"""

def get_person_entities(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    L=[]
    for ent in doc.ents:
        if ent.label_=='PERSON':
            #print(ent.text, ent.start_char, ent.end_char, ent.label_)
            L.append(ent.text)
    #print(L)
    return L

def get_wikipedia_page_text(name,language="en"):
    url = f"https://{language}.wikipedia.org/w/index.php?search={name}"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    text=soup.get_text()
    if language =="en" and (name+" - Wikipedia" in text or name.split(" ")[-1]+" - Wikipedia" in text):
        return get_wikipedia_page_text(name+" (composer)")
    elif language=="fr" and (name+" - Wikipédia" in text or name.split(" ")[-1]+" - Wikipédia" in text):
        return get_wikipedia_page_text(name+" (compositeur)")
    return text

def composer_filter_by_dict(list_of_names, dico):
    """filtre les noms qui sont ceux de compositeurs à partir d'un dictionnaire de compositeurs, évite d'avoir à rechercher dans wikidata à chaque fois donc plus rapide mais moins robuste, à compléter peut-être avec le TD qui utilisait des Trie"""
    list_of_names = list(filter(lambda x: x.strip() in dico, list_of_names))
    return list_of_names

#composer_filter_by_dict(["Richard Wagner","Bach","Mozart"],{"Richard Wagner":(1813,1883),"Johann Sebastian Bach":(1685,1750)})

def composer_filter(list_of_names):
    compo_dico={}
    cpt=0
    for n in list_of_names:
        c_id = find_id(n)
        if c_id is not None and c_id not in compo_dico:
            c = is_composer(c_id,n)
            #print(is_composer(n))
            if c is not None :
                if cpt==0:
                    compo=c
                compo_dico[c_id]=c
                print(n,c_id,f"is the composer number {cpt} found in {compo}'s page")
                cpt+=1
    return compo,compo_dico


def find_compositional_influences(name,fr=False):#problème : l'algo saute souvent Beethoven, y compris chez Wagner
    content = get_wikipedia_page_text(name)
    if fr:
        content+=get_wikipedia_page_text(name,"fr")
    persons = get_person_entities(content)
    return(composer_filter(persons))

def build_list_of_influences(enum_of_composers,french=False):
    list_of_influ_dict=[]
    for composer in enum_of_composers:
        list_of_influ_dict.append(find_compositional_influences(composer,fr=french))
    return list_of_influ_dict



def orienting_with_dates(list_of_dico,compo_dico={}):
    """completing the influences of all encountered compsoers; orienting the influence relations when no doubt exists because of birth-death dates"""

    for compo,dico in list_of_dico:
        cpt=0
        b=False #boolean equal to True iff we have access the the birth date of the first composer
        d=False #boolean equal to True iff we have access the the death date of the first composer
        #print(dico)
        for c in dico.values():

            if c.id not in compo_dico :
                compo_dico[c.id]=c

            if cpt==0: #the first element of each dictionary is the one whose wikipedia page was used to retrieve all the others present in the current dictionary
                #compo = compo_dico[c.id]
                cpt+=1
                print("1st composer of this page :",compo,compo.id,compo_dico[compo.id].influences)
                birth_date_compo = compo.birth
                death_date_compo = compo.death
                if birth_date_compo is not None :
                    print("db:"+str(compo.birth))
                    b = True

                if death_date_compo is not None :
                    print("dd:"+str(compo.death))
                    d = True

            else :
                birth_date = c.birth
                death_date = c.death

                if d and birth_date is not None:
                    if birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        compo_dico[compo.id].influences.add(c)
                        #print(f"added {c} to {compo_dico[compo.id]}")
                    elif b and death_date is not None:
                        if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")
                        else:
                            compo_dico[compo.id].influences.add(c)
                            #print(f"added {c} to {compo_dico[compo.id]} in the new way")
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")
                    else:
                        compo_dico[compo.id].influences.add(c)
                        #print(f"added {c} to {compo_dico[compo.id]}")
                        compo_dico[c.id].influences.add(compo)
                        #print(f"added {compo_dico[compo.id]} to {c}")

                elif b and death_date is not None:
                        if death_date < birth_date_compo+20:#if the current composer c died at most 20 years after the birth of compo we assume compo could not influence c and that only c influenced compo
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")
                        #elif d and birth_date is not None:
                        #    if birth_date > death_date_compo-20:#if compo died at most 2O years after the birth of c then we assume only compo could influence c and not the other way around
                        #        compo_dico[compo.id].influences.add(c)
                        else:
                            compo_dico[compo.id].influences.add(c)
                            #print(f"added {c} to {compo_dico[compo.id]}")
                            compo_dico[c.id].influences.add(compo)
                            #print(f"added {compo_dico[compo.id]} to {c}")

                else:#we cannot say anything for sure since they were contemporary so by default we assume they influenced each other
                    compo_dico[compo.id].influences.add(c)
                    #print(f"added {c} to {compo_dico[compo.id]}")
                    compo_dico[c.id].influences.add(compo)
                    #print(f"added {compo_dico[compo.id]} to {c}")
        print(compo_dico[compo.id],"has influenced",compo_dico[compo.id].influences)

    return compo_dico



def build_graph_from_dict(compo_dico,G=nx.DiGraph()):
    for compo in compo_dico.values():
        print("in build_graph_from_dict",compo,"has influenced",compo.influences)
        for c in compo.influences:
            G.add_edge(compo,c)
            print(f"added {c} to {compo_dico[compo.id]}")

    # save graph object to file
    pickle.dump(G, open(str(next(iter(compo_dico.keys())))+".pickle", 'wb'))
    return G

def graph_of_influences(list_of_compo_names,fr=True,G=nx.DiGraph()):
    list_of_influ_dicts=build_list_of_influences(list_of_compo_names,fr)#put false if you're only interested in the english wiki
    compo_dico = orienting_with_dates(list_of_influ_dicts)
    return build_graph_from_dict(compo_dico,G)

# %%
def prepare_sigma_with_composer_ids(original_graph):
    """Relabels a graph using Composer.id as node labels and returns a Sigma widget."""
    #id_map = {node: int(node.id.replace('Q','')) for node in original_graph.nodes()}
    id_map={node: str(node)+" - "+str(node.id) for node in original_graph.nodes()}
    graph = nx.relabel_nodes(original_graph, id_map)

    # Clean all node/edge attributes to make sure they're JSON serializable
    for n, d in graph.nodes(data=True):
        for k, v in d.items():
            if not isinstance(v, (str, int, float, bool, type(None))):
                d[k] = str(v)

    for u, v, d in graph.edges(data=True):
        for k, val in d.items():
            if not isinstance(val, (str, int, float, bool, type(None))):
                d[k] = str(val)

    layout = {
        node: {
            "x": math.cos(i * 2 * math.pi / len(graph)),
            "y": math.sin(i * 2 * math.pi / len(graph)),
        }
        for i, node in enumerate(graph)
    }

    pagerank_scores = nx.pagerank(graph)

    for k, v in pagerank_scores.items():
        assert isinstance(v, (int, float)), f"Non-numeric pagerank for node {k}: {v}"

    sigma = Sigma(
        graph=graph,
        layout=layout,
        default_edge_type="curve",
        node_border_color_from="node",
        label_font="cursive",
        node_size=pagerank_scores
    )

    return sigma

#prepare_sigma_with_composer_ids(G)
import pickle
from ipysigma import Sigma

def sigma_graph_from_file(filename):
    G = pickle.load(open(filename, 'rb'))
    return G,prepare_sigma_with_composer_ids(G)
    


#G,S = sigma_graph_from_file("Q205519.pickle")
#S
#G=graph_of_influences(["Paul Le Flem","Jean Cras"])
#G=pickle.load(open("Q964256.pickle", 'rb'))
G=pickle.load(open("Q1339.pickle", 'rb'))
S = prepare_sigma_with_composer_ids(G)
S
# Out:
# Sigma(nx.DiGraph with 718 nodes and 1,285 edges)

# %%
"""Louvain"""
"""
Louv=nx.community.louvain.louvain_communities(G,weight='weight')
print("number of communities with Louvain algorithm : ",len(Louv))
print(Louv,"\n")
"""
#K=G.to_undirected(reciprocal=False, as_view=False)
"""k-cliques"""
"""
L=[list(nx.community.k_clique_communities(K,i)) for i in range(2,12)]
lens=list(map(len,L))
print(lens)#number of communities found for each k value between 2 and 11
L=list(nx.community.k_clique_communities(K,5))#for k=5 the maximum number of communities (4) is obtained
print("number of communities with k-cliques algorithm for k = 5 : ", len(L))
print(L,"\n")
"""

"""Girvan-Newman"""
import itertools
"""N=79
comp = nx.community.girvan_newman(K)
for communities in itertools.islice(comp, N):
    print(len(tuple(sorted(c) for c in communities)))"""
k = 4 #number of communities we want to separate
comp = nx.community.girvan_newman(G)
limited = itertools.takewhile(lambda c: len(c) <= k, comp)
i=1
for communities in limited:
    print("number of communities with Girvan-Newman algorithm after", str(i), " iterations : ", len(communities))#tuple(sorted(c) for c in communities)
    i+=1
#print(tuple(sorted(c) for c in communities),"\n")
print(communities)


"""label propagation"""
"""
labcommus=nx.community.label_propagation_communities(G)
print("number of communities with label propagation : ", len(labcommus))
print(labcommus)
"""
# Out:
# number of communities with Girvan-Newman algorithm after 1  iterations :  2
# number of communities with Girvan-Newman algorithm after 2  iterations :  3
# number of communities with Girvan-Newman algorithm after 3  iterations :  4
# ({Percy Grainger, Johann Ambrosius, Ernst Ludwig de Hesse-Darmstadt, Mozart, Q3619312, Q545409, Johann Heinrich Rolle, Q1339, Bach, Marc Matthys, Otto Erich Deutsch, Q1525889, Q183087, Q68255, Ludwig van Beethoven, Adrien Rougier, Q5563833, Q543891, Keith Jarrett, Johann Christoph Bach, Q3638796, Q60965, Jordi Savall, Q3904181, Q67366, Wilhelm Friedrich Ernst Bach, Jacobus Gallus, Albert Schweitzer, Q704174, Reynaldo Hahn, Glenn Gould, Johann Sebastian Bach, Albinoni, Luc-André Marcel, John Coltrane, Poulenc, William A., Henry Lawes, Q3904094, Johann Ernst Bach, Attilio Ariosti, Johann Gottfried Schicht, Bernardo Pasquini, Q215995, Massenet, John Eliot Gardiner, John Christopher Smith, Johann Friedrich Doles, Alessandro Scarlatti, Beck, Vivaldi, Q453100, Joe Hisaishi, Q311625, Johann Gottfried Bernhard, Q960222, Antonio Bernacchi, Heinrich Schütz, Samuel Arnold, Antonio Calegari, Q730234, Johann David Heinichen, Bodin de Boismortier, Q4775711, Q1445590, Wilhelm Friedemann, Q4888380, Q55524, Thierry Escaich, Anthony Hedges, Q314221, Gustav Schreck, Philippe Gaubert, Q875506, Q508635, Michel Corrette, Christoph Graupner, Q1347677, G.F. Handel, Dietrich Buxtehude, Johann Kuhnau, Johannes Galliculus, musicien de ville, Q55758134, John Stanley, Richard Wagner, Q442963, Q57369, Johann Sebastian Bach, Samuel Scheidt, Günther Ramin, Q436126, Antonio Giay, ↑ Paul Badura-Skoda, Wolfgang Jünger, Gottlieb Muffat, Q1339, John Taylor, Mauro Giuliani, Q350221, Alexandre Astier, Q506627, Raphaël Imbert, Jean-Joseph Mouret, Wolfgang Figulus, Brahms, C. P. E. Bach, Q1337261, Wolfgang Schmieder, Q57250484, William Boyce, Charles-Marie Widor, Gounod, William Brade, Johann Hermann Schein, Q4160549, Johann Christian Bach, John Frederick Lampe, John Taylor, Johann Adam Reinken, Jacquet de La Guerre
# , Q679477, Debussy, Q69400, Q554209, Charles Jennens, Telemann, Q57225, François Couperin, McCartney, Messiaen, Scott Speck, Winton Dean, Q1405923, Lorenz Christoph Mizler, Tobias Michael, Johann Krieger, Johann Kuhnau, Q23021179, Corelli, Joseph Bodin de Boismortier, Wilhelm Rust, Karl Richter, Q372593, Reinhard Keiser, ↑ Hogwood, Johann Adolph Hasse, Q1525931, Johann Caspar Kerll, élève de Johann Pachelbel, Giovanni Bononcini, Johann Adam Hiller, jean-christian-michel.com, J. Pachelbel, Filippo Amadei, Q311625, Jean-Adolphe Ier de Saxe-Weissenfels, Q873647, Sebastian Knüpfer, Wilhelm Furtwängler, Charles Gounod, Q213556, Johann Mattheson, Hermann Scherchen, Q395725, Q57829, Q446955, Nicola Porpora, Gustav Leonhardt, Johann Schelle, Q216090, Q959391, Anne Amélie de Prusse, Agostino Steffani, William Crotch, Q323113, Q960222, compositeur de la Chapelle, Q551943, Q7349, Q445121, Gott, Q503355, Q436126, Q64880, Wilhelm Friedemann, Q1710371, Wendy Carlos, Q124772, Antonio Vivaldi, Carl Heinrich Graun, Q435198, Friedrich Wilhelm Zachow, Handel, Q549550, Q91966, Magdalena Bach, Robert Schumann, Girolamo Frescobaldi, Q7302, Johann Nikolaus Forkel, Q377768, John Mainwaring, Gottfried van Swieten, Q60724, maître de chapelle Bach, Nikolaus Harnoncourt, Antonio Lotti, Johann Christoph Friedrich Bach, Christoph Biller, Charles Burney, Q545409, Vincent Lübeck, Q523528, H.C. Robbins, Q157777, Q445696, Francesco Antonio Urio, Éric Lebrun, Padre Martini, Q1526310, Christoph Wolff, Antonio Caldara, Carl Philipp Emanuel Bach, Q46096, Francesco Gasparini, Karl Straube, Q3745255, Domenico Scarlatti, Q691733, Jean-Philippe Rameau, Johann Gottlob Harrer, Q77212, Q104107, Q3836967, Johann Bach, Christoph Graupner, Leonardo Vinci, Giacomo Carissimi, Carl Friedrich Zelter, Quincy Jones, Corelli, Q771789, Couperin}, {Ignaz Schuppanzigh, Giuseppe Verdi
# Jan, Joan Baez, Jeannette Thurber, Richard Wagner, Q159569, Q297717, Carl Loewe, Leonard Bernstein, Q1246313, Saverio Mercadante, François-Joseph Fétis, Friedrich Kalkbrenner, Gioachino Rossini, Antoine Reicha
# , Ludwig van Beethoven Ludwig van Beethoven, Arrigo Boito, Q1151, Ludwig Schnorr von Carolsfeld, Mili Balakirev, Q50333026, Gesang, Wilhelm Furtwängler, Q50187, Mořic Anger, Bettina von Arnim, Q347611, Mylène Farmer, Eduard Marxsen, Q41309, de Rossini, Alfred Einstein, Q90721, Nikolaus Zmeskall, Johann Wolfgang von Goethe
# , Q69376, Wilhelm Müller, Q315150, Hector Berlioz, Mili Balakirev, Tarja Turunen, Q7294, Q374582, Q2000816, Félicien David, Sergiu Celibidache, Q2430552, Bruckner, Antoine Reicha
# , Jan Swafford, Q213558, Joaquín Turina, Q434601, Josef Hellmesberger, Felix Mendelssohn, Q78524, Johann Herbeck, Q77177, Yasuaki Shimizu, Q286062, Q57210, Giuseppe Verdi
# Jan, Vincent d'Indy, Luigi Boccherini, Claudio Abbado, Hans von Bülow, Carl Loewe, Q110224410, Amadeus Hoffmann, Giuseppe Verdi
# Jan, Anselm Hüttenbrenner, Sigismund Thalberg, Modeste Moussorgski, Leonard Bernstein, Antonín Dvořák, Johann Strauss, Charles Villiers Stanford, Wilhelm Backhaus, Q7934272, Karl Böhm, Barry Cooper, Kaija Saariaho, Q5434007, Victor Herbert, Mahler, Q200867, Giacomo Meyerbeer, Karel Ancerl, Clara Schumann, Günter Raphael, de Nikolaus Harnoncourt, Paul Badura-Skoda, Richard Wagner, Ralph Vaughan Williams, Johann Strauss, Alexandre Borodine
# , Joaquín Rodrigo
# , Johann Georg Albrechtsberger, Q5298438, Jarmil Burghauser, Robert Schumann, Q35624448, Q151953, Richard Wagner, Q200867, Leevi Madetoja, Q255, Q457711, Giacomo Meyerbeer, Amadeus Hoffmann, Q215333, Q311387, Q16013625, Alexandre Borodine
# , Anton Schindler, Kaspar Anton Karl van Beethoven, Brahms, Q6013167, Clara Schumann, bon musicien, Q544277, Bruckner, Daniel Gottlob Türk, Mendelssohn, Karel Bendl, Joséphine von Brunsvik, Gustav Mahler, Brahms, Fanny Mendelssohn, Louis Ehlert, Ignaz Seyfried, Horatio Parker, Johann Wolfgang von Goethe
# , Q310431, Karel Ančerl, Fanny Mendelssohn, Joseph Joachim, Rodolphe Kreutzer, Mikhaïl Glinka, Nannette Streicher, András Schiff, Ján Cikker, Carl Czerny, Modeste Moussorgski, Mikhaïl Glinka, Josef Suk, ami de Schubert, Q41309, Claudio Abbado, Liszt, Johann Michael Vogl, Franz Clement, Q57178, Christophe Looten, Oskar Nedbal, Mikhaïl Glinka, Q155540, Carl Schuricht, Carl Loewe, Clara Schumann, Karel Knittl, Q721465, Q447851, Liszt, Félicien David, Andreas Streicher, Q93373, Carl Maria von Weber, Q347611, Robert Levin, Hans von Bulow, Q4974772, Ferdinand von Waldstein, Q66818, Louis Spohr, Q724497, Q721465, Q60908, Mel Bonis, Q270464, Q215083, Q565548, Q5126007, Anton Schindler, Woody Allen, Q322210, Alexander Dargomyzhsky, Q322323, Q819749, Josef Suk, Philippe Autexier, Ignaz Moscheles, Carl Nielsen, Louise Japha, Schubert, Ignaz Schuppanzigh, Ferdinand David, Q46096, Janet Baker, Anton Diabelli, Johann Franz Xaver Sterkel, Arnold Schoenberg, Friedrich Kalkbrenner, Xavier Darasse, Robert Schumann, Q713949, Q20004429, Alexander Moyzes
# , Mel Bonis, Q1029284, Duke Ellington, Károly Goldmark, Q45682, Q2399157, Q119432, Johann van Beethoven, Benjamin Britten, Eduard Hanslick, Alexandre Borodine
# , Chopin, Antonio Salieri, Q701340, Brahms, Q45825712, Wolfgang Amadeus Mozart, Witold Lutosławski, Wilhelm Furtwängler, Dmitri Shostakovich, Hans von Bülow, Bruno Walter
# Pianistes, Mogens Wöldike, Sigismund Thalberg, Karl Böhm, Heinz Holliger, Felix Mendelssohn, Otto Jahn, Ignacy Paderewski, Yo-Yo Ma, Q7298, Schubert, Q17634412, Nikolai Rimsky-Korsakov, Magnus Lindberg, Bettina von Arnim, François Schubert, Karel Komzák's, Arnold Alschwang, Bernard Zweers
# , Rafael Kubelík, de composer deux, Robert Schumann, Thomas Adès, Czech Composer, Robert Schumann, Aulis Sallinen, Carlos Chávez, Silvestre Revueltas, Boleslav Yavorsky, Q6004693, Q1159997, Q519693, Q881741, Mili Balakirev, Pyotr Ilyich Tchaikovsky, Jonathan Berger, Webern, Q953007, de la guerre, Q366536, Q113484550, Q1351430, Anton Bruckner, Q16334134, Franz von Schober, Alfred Brendel, Tristan Murail, Joseph von Spaun, Q323435, Pierre Bartholomée, Leonid Nikolayev, Q467738, Q80135, Ernst Hilmar, Q255300, Eduard Hanslick, Johann Friedrich Schubert, William Walton, David Haas, Mel Bonis, Giuseppe Tartini, Q312700, Aaron Copland, Alexander Borodin, Joseph Joachim, Tikhon Khrennikov, Ian McDonald, George Enescu
# , Q771789, Lev Oborin, Brahms, Donald Tovey, Harrison Birtwistle, Q2394722, Q437262, František Ondříček, Miaskovski, Johann Mayrhofer, Q7298, Q368583, Rafael Kubelík, Q157785, Q153776, Otto Erich Deutsch, Q5460707, Gavriil Popov, Q706139, Antonio Salieri, Felix Draeseke, Q56310080, Q97274399, Q5416317, Q2194365, Olivier Messiaen, Q8112426, Zoltán Kodály, Q152043, Murray Schafer, Paul Hindemith, Q2142506, Q5592848, Fritz Stiedry, Brahms, Q565070, Arthur Honegger, Q1939469, Witold Lutosławski, Krzysztof Meyer, Dmitry Kabalevsky, Ferdinand Schubert, Louis van Beethoven, Maximilian Steinberg, Q1988504, Q726973, Franz Anton Schubert, Johann Philipp Kirnberger, Stravinsky, Keith Jarrett, Sigismund Thalberg, Q3180496, Q48363, Ignacy Paderewski, Gerard McBurney, Q706221, Q202672, Nikolaus Harnoncourt, Josef Zvonař, Henry Cowell, Niels Gade, Jordi Savall, Johann Philipp Neumann, Evelyn Glennie, Q311389, Nicolas Nabokov, Brian Newbould, Sergei Prokofiev, Nepomuk Maýr, Vissarion Shebalin, Franz Liszt, Robin Holloway, Q2062832, Edward MacDowell, Kaija Saariaho, Paganini, Szpinalski, Arvo Pärt, Q1029423, Fiodor Droujinine, Antonín Bennewitz, Leopold Stokowski, Q312700, András Schiff, Leonidas Kavakos, Harry Burleigh, Q232255, Aram Khachaturian, Joonas Kokkonen, Q11457729, Antonio Zingarelli, Mstislav Rostropovich, Q724254, Heinrich Isaac, Q778890, Hans Abrahamsen, Q58008, John Eliot Gardiner, Carl Maria von Bocklet, Q534512, Bruno Walter, Enrique Granados
# , Andrés Segovia, Paul Badura-Skoda, Claude Vivier, Q1280917, György Kurtág, Giovanni Paisiello, Modeste Moussorgski, Krystian Zimerman, Bettina von Arnim, Peter Schreier, Grigory Ginzburg, musicien de tous, Usko Meriläinen, Esa-Pekka, Dvorak, Arturo Toscanini, Giacomo Meyerbeer, Woody Allen, Franz Liszt, Leonard Bernstein, Janet Baker, Otilie Suková, Kirill Zaborov, Jean Sibelius, Q709658, Bedřich Smetana, Sofia Gubaidulina, Benjamin Britten, Richard Wagner, Q531569, Leoš Janáček, Lev Lebedinsky, Floex, Erik Bergman, Q191917, Rudolf Tobias, György Ligeti, Giacomo Meyerbeer, Miles Davis, Josef Foerster, Anton Bruckner, Alexander Glazunov, Q710458, Q55214796, Antonín Liehmann, Elmira Nazirova, Pierre Boulez, Josef Bohuslav Foerster}, {Ludwig von Köchel, Johann Michael Puchberg, Q362139, Mathias Haydn Mathias Haydn, Q882123, Q313917, Franz Xavier Süssmayer, Marianne de Martines, de Paul II Anton Esterházy, Arrigo Boito, Robbins Landon, Q768095, Q25999335, Cimarosa, Anton Wranitzky, Joseph Legros, Luigia Polzelli, Christopher Hogwood, Michael Haydn, Robert Levin, Johann Schobert, Friedrich Kalkbrenner, Leopold Mozart, Alfred Einstein, Ignacy Paderewski, Q254, Woody Allen, Robert Levin, Maria Wilhelmine Thun, Arthur Hutchings, Gluck, Gluck, Giuseppe Verdi, Brahms, ↑ Wolfgang, Wolfgang Hildesheimer, Clementi, Pietro Antonio Lorenzoni, Charles Rosen, Muzio Clementi, Claudio Abbado, Otto Erich Deutsch, Pierre Barbaud, Antonio Polzelli, Christian Cannabich, Grétry, Karl Friedrich Abel, Q14421, Marianne von Genzinger, Joseph Weigl, Q5045261, Thomas Linley, Q157898, Ignaz Pleyel, Howard Chandler Robbins Landon, ↑ Tia DeNora, Franz von Walsegg, Q151953, Roman Hoffstetter, Joseph Haydn, Luigi Tomasini, de chapelle Werner, librettiste Lorenzo da Ponte, Johann Strauss II, Charles Burney, Michael Haydn, jeune compositeur, George Bridgetower, Gottfried van Swieten, Emanuel Schikaneder, Q154812, Luigi Cherubini, Gioachino Rossini, Peter Hänsel, autrichien de la période, Freystadler, Wolfgang Mozart, Q698066, Johannes Brahms, Giacomo Meyerbeer, Q310518, Q1712216, ↑ Philippe Autexier, Nicola Porpora, Giovanni Paisiello, Jacques Chailley, Karl Thomas Mozart, Mozart de Bologne, Joseph Lange, Mozart, Robert Kimmerling, Jean-Chrétien Bach, Mendelssohn, Carl Maria von Weber, Abund Mikysch, Antonín Kraft, Paul Wranitzky, Nicolas Slonimsky, Q672225, Q1348126, Léopold Mozart, Joseph Legros, Benjamin Britten, Johann Spech, Jason Schwartzman, Paul Badura-Skoda, Albert Christoph Dies, Beethoven, David Wyn Jones, Maria Anna Mozart, Schubert, Carl Friberth, Johann Peter Salomon, Leopold Mozart, George Sand, Louis Spohr, Robert Schumann, Eva Badura-Skoda, Johann Tost, Anton Walter, Joseph Haydn, Wolfgang Amadeus Mozart, Joseph Haydn, Patrick Taïeb, Franciszek Lessel, Witold Lutosławski, Johann Joseph Fux, Q697804, Nicolas Ier Joseph Esterházy, maître de chœur, György Ligeti, ↑ Henri Kling, Q157777, Q20665628, András Schiff, Mozart, Nicolas II Esterházy, Gluck, Q79104, Q272236, Antonio Salieri, Q113911, Q43704749, Johann Nepomuk Hummel, Kaija Saariaho, Q689576, Q3816382, Q316903, Luigi Cherubini, d'orchestre qu'il, de Salieri, Arthur Honegger, Q215333, Saverio Mercadante}, {Félicien David, Giacomo Meyerbeer, Mili Balakirev, Tchaikovsky, Hector Berlioz, Claudio Abbado, Sigismund Thalberg, Jean-Baptiste Robin, Antoine Reicha
# , Felix Mendelssohn, Michel Corboz, Mikhaïl Glinka, Anton Bruckner, Woody Allen, Otto Klemperer, Fanny Mendelssohn, Johann Wolfgang von Goethe
# , Johann Christian Lobe, Giuseppe Verdi
# Jan, Q69376, Clara Schumann, Niels Wilhelm Gade, Philippe Herreweghe, Friedrich Kalkbrenner, Robert Schumann, Richard Wagner, Alexandre Borodine
# , Delphine von Schauroth, Liszt, Edward Dannreuther, Joseph Joachim Raff, Bettina von Arnim, Mel Bonis, Wilhelm Furtwängler, Carl Friedrich Zelter, Q214805, Carl Loewe, Rena Kyriakou, Modeste Moussorgski})
# '\nlabcommus=nx.community.label_propagation_communities(G)\nprint("number of communities with label propagation : ", len(labcommus))\nprint(labcommus)\n'

# %%
from composer import * 
#g=pickle.load(open("Q964256.pickle", 'rb'))
#g=pickle.load(open("Q1339.pickle",'rb'))
g=pickle.load(open("Q205519.pickle",'rb'))
id_map={node: str(node)+" - "+str(node.id) for node in g.nodes()}
graph = nx.relabel_nodes(g, id_map)

# Clean all node/edge attributes to make sure they're JSON serializable
for n, d in graph.nodes(data=True):
    for k, v in d.items():
        if not isinstance(v, (str, int, float, bool, type(None))):
            d[k] = str(v)

for u, v, d in graph.edges(data=True):
    for k, val in d.items():
        if not isinstance(val, (str, int, float, bool, type(None))):
            d[k] = str(val)

"""layout = {
    node: {
        "x": math.cos(i * 2 * math.pi / len(graph)),
        "y": math.sin(i * 2 * math.pi / len(graph)),
    }
    for i, node in enumerate(graph)
}"""

pagerank_scores = nx.pagerank(graph)

for k, v in pagerank_scores.items():
    assert isinstance(v, (int, float)), f"Non-numeric pagerank for node {k}: {v}"

era_categories = ["Medieval","Baroque", "Classique", "Romantique", "XXe", "contemporain"]
"""colors = {
    "Medieval": "#654321", #Brown
    "Baroque": "#2ECC71",      # Green
    "Classique": "#F1C40F",    # Yellow
    "Romantique": "#E74C3C",       # Red
    "XXe": "#3498DB",  # Blue
    "contemporain": "#7F00FF", #Lilac
    "Unknown": "#95A5A6"
    
}"""


"""Girvan-Newman"""
import itertools
import matplotlib.colors as mcolors
"""N=79
comp = nx.community.girvan_newman(K)
for communities in itertools.islice(comp, N):
    print(len(tuple(sorted(c) for c in communities)))"""
k = 6 #number of communities we want to separate
comp = nx.community.girvan_newman(g)
limited = itertools.takewhile(lambda c: len(c) <= k, comp)
i=1
for communities in limited:
    print("number of communities with Girvan-Newman algorithm after", str(i), " iterations : ", len(communities))#tuple(sorted(c) for c in communities)
    i+=1
#print(tuple(sorted(c) for c in communities),"\n")
#print(communities)
# Generate a list of distinct colors
color_list = list(mcolors.TABLEAU_COLORS.values()) + list(mcolors.CSS4_COLORS.values())
np.random.shuffle(color_list)


# Assign a unique color to each community
node_to_color = {}
for i, community in enumerate(communities):
    color = color_list[i % len(color_list)]
    for node in community:
        label = f"{str(node)} - {node.id}"
        node_to_color[label] = color

# Apply colors to nodes
for node_label in graph.nodes:
    graph.nodes[node_label]["color_node"] = node_to_color.get(node_label, "#95A5A6")  # Gray fallback

partitions = {"Medieval":[],"Baroque":[], "Classique":[], "Romantique":[], "XXe":[], "contemporain":[],"Unknown":[]}

for node in g.nodes:
    era = node.get_era()  # Default to "medium"
    #graph.nodes[str(node)+" - "+str(node.id)]["color_node"] = color.get(era, "#95A5A6")  # Gray if unknown
    #g.nodes[node]["size"] = 10  # Set a default size
    #partitions[era].append(graph.nodes[str(node)+" - "+str(node.id)])
    partitions[era].append(str(node)+" - "+str(node.id))


for source, target in graph.edges:
    graph.edges[source, target]["color_edge"] = graph.nodes[target]["color_node"]

layout = {}

# Grid positions for each era cluster center
grid_positions = {
    "Medieval": (0, 0),
    "Baroque": (-3, 0),
    "Classique": (0, 2),
    "Romantique": (3, 0),
    "XXe": (-2, -2),
    "contemporain": (2, -2)
}

# Assign circular layouts within each cluster
for era, node_names in partitions.items():
    base_x, base_y = grid_positions.get(era, (0, 0))
    angle_step = 2 * np.pi / max(1, len(node_names))
    radius = 1.5  # Distance from center of cluster

    for i, node_name in enumerate(node_names):
        angle = i * angle_step
        layout[node_name] = {
            "x": base_x + radius * np.cos(angle),
            "y": base_y + radius * np.sin(angle)
        }

# Visualize with ipysigma
sigma = Sigma(
    graph,
    raw_node_color="color_node",
    raw_edge_color="color_edge",
    layout=layout,
    node_label="label",
    default_edge_type="curve",
    node_border_color_from="node",
    label_font="cursive",
    node_size=graph.out_degree()
    #nx.pagerank(graph)
)

sigma

import json

# Prepare export data
export_data = {
    "nodes": [
        {
            "id": str(n),
            "x": layout.get(n, {}).get("x", 0),
            "y": layout.get(n, {}).get("y", 0),
            "label": graph.nodes[n].get("label", str(n)),
            "color": graph.nodes[n].get("color_node", "#999999"),
            "size": graph.nodes[n].get("size", 1)
        }
        for n in graph.nodes
    ],
    "edges": [
        {
            "source": u,
            "target": v,
            "color": graph.edges[u, v].get("color_edge", "#999999"),
            "type": graph.edges[u, v].get("type", "curve")
        }
        for u, v in graph.edges
    ]
}

# Write to file
with open("sigma_graph.json", "w") as f:
    json.dump(export_data, f, indent=2)
# Out:
# number of communities with Girvan-Newman algorithm after 1  iterations :  2
# number of communities with Girvan-Newman algorithm after 2  iterations :  3
# number of communities with Girvan-Newman algorithm after 3  iterations :  4
# number of communities with Girvan-Newman algorithm after 4  iterations :  5
# number of communities with Girvan-Newman algorithm after 5  iterations :  6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 70
#      68     color = color_list[i % len(color_list)]
#      69     for node in community:
# ---> 70         label = f"{str(node)} - {node.id}"
#      71         node_to_color[label] = color
#      73 # Apply colors to nodes
#
# AttributeError: 'str' object has no attribute 'id'
